# %% [markdown]
# ## NBA GM Signings Analysis

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import requests
import time
import json
from bs4 import BeautifulSoup
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.image as mpimg
from PIL import Image

# %%
years = list(range(2022,2025))

# %% [markdown]
# ### Pulling in Saved Data from Basketball Reference

# %%
winshares_df = pd.read_csv('../inputs/win_shares_stats_2022_2024.csv')

# %% [markdown]
# ### Combine with Google Sheet Data

# %%
signings_df = pd.read_csv('../inputs/gm_signings_2022_2024.csv')

# %% [markdown]
# ### Merging Data

# %%
merged_df = pd.merge(signings_df, winshares_df[['Player', 'Year', 'Tm', 'WS']], 
                     left_on=['Acquired Player', 'Season', 'Team Acquiring'], 
                     right_on=['Player', 'Year', 'Tm'], 
                     how='left')

# %%
signings_df['Acquired Player Win Shares Year 1'] = merged_df['WS']

# %%
merged_df_year2 = pd.merge(signings_df, winshares_df[['Player', 'Year', 'Tm', 'WS']], 
                     left_on=['Acquired Player', 'Year 2', 'Team Acquiring'], 
                     right_on=['Player', 'Year', 'Tm'], 
                     how='left')

# %%
signings_df['Acquired Player Win Shares Year 2'] = merged_df_year2['WS']

# %% [markdown]
# This creates a dataset that has players that signed with a new team from 2022-2024 and their respective performance in the subsequent seasons.

# %%
signings_df.isna().sum()
# Out:
# Season                                 0
# Team Acquiring                         0
# Acquired Player                        0
# Team Losing                            1
# Acquisition Type                       0
# Acquiring GM                           0
# Losing GM                             13
# Year 2                                 0
# Helper                                 0
# AAV                                    0
# One Year?                              0
# Acquired Player Win Shares Year 1     35
# Acquired Player Win Shares Year 2    168
# dtype: int64

# %%
signings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Season                             201 non-null    int64
#  1   Team Acquiring                     201 non-null    object
#  2   Acquired Player                    201 non-null    object
#  3   Team Losing                        200 non-null    object
#  4   Acquisition Type                   201 non-null    object
#  5   Acquiring GM                       201 non-null    object
#  6   Losing GM                          188 non-null    object
#  7   Year 2                             201 non-null    int64
#  8   Helper                             201 non-null    object
#  9   AAV                                201 non-null    float64
#  10  One Year?                          201 non-null    object
#  11  Acquired Player Win Shares Year 1  166 non-null    object
#  12  Acquired Player Win Shares Year 2  33 non-null     object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 20.5+ KB

# %% [markdown]
# From here it looks most players (168/201) in this dataset did not stay on the same team in year 2 after the acquisition.

# %%
signings_df[signings_df['Acquired Player'] == 'Lauri Markkanen']
# Out:
#      Season Team Acquiring  Acquired Player Team Losing Acquisition Type  \
# 121    2022            CLE  Lauri Markkanen         CHI          Signing
#
#     Acquiring GM      Losing GM  Year 2               Helper    AAV One Year?  \
# 121  Koby Altman  Marc Eversley    2023  2022Lauri Markkanen  16.75        No
#
#     Acquired Player Win Shares Year 1 Acquired Player Win Shares Year 2
# 121                               5.0                               NaN

# %%
winshares_df[winshares_df['Player'] == 'Lauri Markkanen']
# Out:
#                Player Pos Age   Tm   G    MP   PER   TS%  3PAr   FTr  ...  \
# 490   Lauri Markkanen  SF  24  CLE  61  1878  14.7  .582  .541  .226  ...
# 1249  Lauri Markkanen  PF  25  UTA  66  2273  22.1  .640  .446  .348  ...
# 1967  Lauri Markkanen  PF  26  UTA  55  1820  21.5  .631  .493  .311  ...
#
#       USG%  OWS  DWS   WS WS/48 OBPM  DBPM  BPM VORP  Year
# 490   19.5  2.7  2.3  5.0  .127  0.4  -0.1  0.4  1.1  2022
# 1249  26.6  6.3  1.9  8.2  .173  4.9  -1.0  3.8  3.3  2023
# 1967  25.0  5.2  0.9  6.2  .163  5.1  -1.5  3.6  2.6  2024
#
# [3 rows x 27 columns]

# %%
signings_df[signings_df['Acquired Player'] == 'Jalen Brunson']
# Out:
#      Season Team Acquiring Acquired Player Team Losing Acquisition Type  \
# 151    2023            NYK   Jalen Brunson         DAL          Signing
#
#     Acquiring GM      Losing GM  Year 2             Helper   AAV One Year?  \
# 151  Scott Perry  Nico Harrison    2024  2023Jalen Brunson  26.0        No
#
#     Acquired Player Win Shares Year 1 Acquired Player Win Shares Year 2
# 151                               8.7                              11.2

# %%
winshares_df[winshares_df['Player'] == 'Jalen Brunson']
# Out:
#              Player Pos Age   Tm   G    MP   PER   TS%  3PAr   FTr  ...  USG%  \
# 102   Jalen Brunson  SG  25  DAL  79  2524  17.1  .583  .250  .211  ...  21.9
# 937   Jalen Brunson  PG  26  NYK  68  2379  21.2  .597  .269  .328  ...  27.2
# 1659  Jalen Brunson  PG  27  NYK  77  2726  23.4  .592  .319  .302  ...  32.5
#
#       OWS  DWS    WS WS/48 OBPM  DBPM  BPM VORP  Year
# 102   4.9  2.7   7.5  .143  0.9   0.0  0.9  1.9  2022
# 937   6.9  1.8   8.7  .175  4.4  -0.5  3.9  3.5  2023
# 1659  8.8  2.4  11.2  .198  6.3  -0.4  5.8  5.4  2024
#
# [3 rows x 27 columns]

# %% [markdown]
# The two examples shows that our Acquired Player BPM/WARP Year 2 calculation only pulls in if the player stayed with the team that acquired them in the second year. This is what we want - if they no longer have the player, the value they brought on doesn't help.

# %% [markdown]
# ## Aggregation and Visualization

# %% [markdown]
# ### Cost per Win Share

# %%
# Convert 'AAV' and 'Acquired Player BPM/WARP Year 1' to numeric, coercing errors to NaN
signings_df['AAV'] = pd.to_numeric(signings_df['AAV'], errors='coerce')
signings_df['Acquired Player Win Shares Year 1'] = pd.to_numeric(signings_df['Acquired Player Win Shares Year 1'], errors='coerce')

# Group by 'Acquiring GM' and 'Team Acquiring', then calculate the sum and count
grouped_year1 = signings_df.groupby(['Acquiring GM', 'Team Acquiring']).agg({
    'AAV': 'sum',
    'Acquired Player Win Shares Year 1': 'sum',
    'Acquiring GM': 'count'  # Using 'count' to get the number of entries per group
})

# Rename the count column for clarity
grouped_year1 = grouped_year1.rename(columns={'Acquiring GM': 'Count'})

# Calculate the ratio of AAV to Acquired Player BPM/WARP Year 1
grouped_year1['Cost of Win Share'] = grouped_year1['AAV'] / grouped_year1['Acquired Player Win Shares Year 1']

# Reset index for easier plotting
grouped_year1 = grouped_year1.reset_index()

# %%
grouped_year1 = grouped_year1.rename(columns={'AAV': 'AAV_sum'})

# %%
grouped_year1['Win Shares per Million'] = 1 / grouped_year1['Cost of Win Share']

# %%
grouped_year1
# Out:
#          Acquiring GM Team Acquiring  AAV_sum  \
# 0       Andy Elisburg            MIA    48.62
# 1      Anthony Parker            ORL    11.00
# 2           Bob Myers            GSW    13.91
# 3       Bobby Webster            TOR    29.89
# 4        Brad Stevens            BOS    29.90
# 5        Brian Wright            SAS    31.30
# 6        Calvin Booth            DEN    23.40
# 7       Chad Buchanan            IND    34.08
# 8         Daryl Morey            PHI    31.22
# 9         James Jones            PHO    26.10
# 10         Joe Cronin            POR    19.49
# 11       John Hammond            ORL     2.91
# 12          Jon Horst            MIL    27.24
# 13       Justin Zanik            UTA    13.57
# 14        Koby Altman            CLE    55.33
# 15      Landry Fields            ATL     6.50
# 16          Leon Rose            NYK    13.80
# 17      Marc Eversley            CHI    74.59
# 18     Michael Winger            LAC    17.95
# 19  Mike Dunleavy Jr.            GSW    19.30
# 20      Mitch Kupchak            CHO    21.52
# 21       Monte McNair            SAC    30.24
# 22      Nico Harrison            DAL    47.40
# 23       Rafael Stone            HOU    86.99
# 24        Rob Pelinka            LAL    69.00
# 25         Sam Presti            OKC     2.00
# 26        Scott Perry            NYK    63.60
# 27         Sean Marks            BRK    30.53
# 28       Tim Connelly            MIN    12.10
# 29     Tommy Sheppard            WAS    21.85
# 30     Trajan Langdon            NOP    18.75
# 31     Travis Schlenk            ATL     5.84
# 32        Troy Weaver            DET    15.20
# 33       Will Dawkins            WAS    10.90
# 34       Zach Kleiman            MEM     2.40
#
#     Acquired Player Win Shares Year 1  Count  Cost of Win Share  \
# 0                                15.4      5           3.157143
# 1                                 2.6      1           4.230769
# 2                                 4.6      4           3.023913
# 3                                -0.5      8         -59.780000
# 4                                 4.2     10           7.119048
# 5                                 4.9      6           6.387755
# 6                                13.5      6           1.733333
# 7                                 4.7      5           7.251064
# 8                                14.1      9           2.214184
# 9                                18.4     10           1.418478
# 10                                2.7      7           7.218519
# 11                                0.8      1           3.637500
# 12                               10.3      7           2.644660
# 13                                8.5      4           1.596471
# 14                               14.8      9           3.738514
# 15                                1.8      3           3.611111
# 16                                6.5      2           2.123077
# 17                               19.8     10           3.767172
# 18                                6.4      3           2.804688
# 19                                6.6      4           2.924242
# 20                               -0.2      5        -107.600000
# 21                                6.6      8           4.581818
# 22                               11.0      9           4.309091
# 23                               16.9      6           5.147337
# 24                               28.4     24           2.429577
# 25                                3.8      1           0.526316
# 26                               18.8      5           3.382979
# 27                               13.0     13           2.348462
# 28                                1.7      4           7.117647
# 29                                1.7      2          12.852941
# 30                                4.4      3           4.261364
# 31                                1.2      2           4.866667
# 32                                1.6      2           9.500000
# 33                                4.5      2           2.422222
# 34                                0.4      1           6.000000
#
#     Win Shares per Million
# 0                 0.316742
# 1                 0.236364
# 2                 0.330697
# 3                -0.016728
# 4                 0.140468
# 5                 0.156550
# 6                 0.576923
# 7                 0.137911
# 8                 0.451634
# 9                 0.704981
# 10                0.138533
# 11                0.274914
# 12                0.378120
# 13                0.626382
# 14                0.267486
# 15                0.276923
# 16                0.471014
# 17                0.265451
# 18                0.356546
# 19                0.341969
# 20               -0.009294
# 21                0.218254
# 22                0.232068
# 23                0.194275
# 24                0.411594
# 25                1.900000
# 26                0.295597
# 27                0.425811
# 28                0.140496
# 29                0.077803
# 30                0.234667
# 31                0.205479
# 32                0.105263
# 33                0.412844
# 34                0.166667

# %% [markdown]
# ### Adding in Modeling Component - What Should the Cost of 1 Win Share Be?

# %%
grouped_year1.columns
# Out:
# Index(['Acquiring GM', 'Team Acquiring', 'AAV_sum',
#        'Acquired Player Win Shares Year 1', 'Count', 'Cost of Win Share',
#        'Win Shares per Million'],
#       dtype='object')

# %%
features = grouped_year1['AAV_sum'].values.reshape(-1, 1)
target = grouped_year1['Acquired Player Win Shares Year 1']

# %%
lm = LinearRegression()
lm.fit(features,target)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame(lm.coef_,index=['AAV_sum'],columns=['Coefficient'])
coeff_df
# Out:
#          Coefficient
# AAV_sum     0.262287

# %% [markdown]
# The linear regression uses the sum of salaries of each GM's transactions as the feature and the first year win shares as the target. This yields a coefficient of 0.26, which means 1.0 million leads to 0.26 win shares. The below calculation shows that one win share costs $3.81 million.

# %%
cost_win_share_modeled = 1 / coeff_df['Coefficient'].iloc[0]
cost_win_share_modeled
# Out:
# 3.81262326578587

# %%
# Scatter plot with line of best fit
plt.figure(figsize=(8,6))
sns.regplot(x='AAV_sum', y='Acquired Player Win Shares Year 1', data=grouped_year1, line_kws={"color": "red"})

# Adding labels and title
plt.xlabel('AAV (Average Annual Value)')
plt.ylabel('Acquired Player Win Shares Year 1')
plt.title('AAV vs Acquired Player Win Shares Year 1 with Best Fit Line')

# Show plot
plt.show()

# %% [markdown]
# The regression yields a cost per win share of $3.81 million. The raw calculation below is used to just gut check that number.

# %%
aav_sum = grouped_year1['AAV_sum'].sum()
win_shares_sum = grouped_year1['Acquired Player Win Shares Year 1'].sum()

cost_win_share_raw = aav_sum / win_shares_sum
print(cost_win_share_raw)
# Out:
# 3.5356699525374227

# %%
# Group by 'Acquiring GM' and 'Team Acquiring', then calculate the sum and count
grouped_year1_by_season = signings_df.groupby(['Season', 'Acquiring GM', 'Team Acquiring']).agg({
    'AAV': 'sum',
    'Acquired Player Win Shares Year 1': 'sum',
    'Acquiring GM': 'count'  # Using 'count' to get the number of entries per group
})

# Rename the count column for clarity
grouped_year1_by_season = grouped_year1_by_season.rename(columns={'Acquiring GM': 'Count'})

# Calculate the ratio of AAV to Acquired Player BPM/WARP Year 1
grouped_year1_by_season['Cost of Win Share'] = grouped_year1_by_season['AAV'] / grouped_year1_by_season['Acquired Player Win Shares Year 1']

# Reset index for easier plotting
grouped_year1_by_season = grouped_year1_by_season.reset_index()

# %%
grouped_year1_by_season = grouped_year1_by_season.rename(columns={'AAV': 'AAV_sum'})

# %%
# Group by 'Season' and calculate the sum of 'AAV' and 'Acquired Player Win Shares Year 1' for each season
grouped_by_season = grouped_year1_by_season.groupby('Season').agg({
    'AAV_sum': 'sum',
    'Acquired Player Win Shares Year 1': 'sum'
})

# Calculate cost per win share for each season
grouped_by_season['Cost Per Win Share'] = grouped_by_season['AAV_sum'] / grouped_by_season['Acquired Player Win Shares Year 1']

print(grouped_by_season[['Cost Per Win Share']])
# Out:
#         Cost Per Win Share
# Season
# 2022              3.410081
# 2023              3.240366
# 2024              3.999746

# %% [markdown]
# Recreating the cost per win share plot from earlier with a line for the average cost per win share as a reference.

# %%
grouped_year1['Team Acquiring'].unique()
# Out:
# array(['MIA', 'ORL', 'GSW', 'TOR', 'BOS', 'SAS', 'DEN', 'IND', 'PHI',
#        'PHO', 'POR', 'MIL', 'UTA', 'CLE', 'ATL', 'NYK', 'CHI', 'LAC',
#        'CHO', 'SAC', 'DAL', 'HOU', 'LAL', 'OKC', 'BRK', 'MIN', 'WAS',
#        'NOP', 'DET', 'MEM'], dtype=object)

# %%
# Set up the plot size with reduced height
plt.figure(figsize=(10, 10))  # Adjust the height here

# Create a horizontal bar chart using seaborn
sns.barplot(y='Acquiring GM', x='Cost of Win Share', data=grouped_year1, color='gray')

# Add labels and title
plt.title('Cost of Win Share in Year 1 by GM')
plt.xlabel('Cost of Win Share')
plt.ylabel('Acquiring GM')

# Set the x-axis limits to show only positive values
plt.xlim(0, plt.xlim()[1])  # Lower limit is set to 0, upper limit remains unchanged

# Set the y-axis limits to keep bars within a certain height
plt.ylim(-0.5, len(grouped_year1) - 0.5)  # Adjust y-axis limits to fit the number of bars

# Add a black reference line for the modeled cost of a win share
plt.axvline(x=cost_win_share_modeled, color='black', linestyle='--', label=f'Modeled Cost of Win Share: ({cost_win_share_modeled:.2f})')

# Add an annotation with a multi-line text box aligned to the far right
plt.text(
    x=plt.xlim()[1] * 0.98,  # Position near the far right of the x-axis
    y=len(grouped_year1) * 0.1,  # Adjusted vertical position
    s="The lower the cost per win share,\nthe better as it means the GM\nis more efficient in acquiring value.\nBlack line is average cost per win share.",
    ha='right',  # Align text to the right
    va='top',  # Vertical alignment to the top
    color='black',
    fontsize=10,
    bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white", linewidth=0.5, alpha=0.9),
)

# Add larger team logos to the right of each bar
for i, (index, row) in enumerate(grouped_year1.iterrows()):
    team_name = row['Team Acquiring']  # Assuming 'Team Acquiring' has the team names
    logo_path = f'../logos/{team_name}.png'  # Update with actual path to logos
    
    # Load the logo image
    img = Image.open(logo_path)
    
    # Resize the image (width, height) - 100% larger than previous size
    img = img.resize((90, 44), Image.ANTIALIAS)  # Increased size to 90x44
    img = mpimg.imread(logo_path)  # Convert back to numpy array after resizing
    
    # Set the position for the logo to the right of each bar
    plt.imshow(img, aspect='auto', extent=[row['Cost of Win Share'] + 0.1, row['Cost of Win Share'] + 0.7, 
                                            i - 0.4, i + 0.4], zorder=5)

# Align y-axis labels with bars by setting the ticks and labels manually
plt.yticks(ticks=range(len(grouped_year1)), labels=grouped_year1['Acquiring GM'], rotation=0)

# Add a legend for the reference line
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_18368\415213732.py:42: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((90, 44), Image.ANTIALIAS)  # Increased size to 90x44

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = grouped_year1['Cost of Win Share'].quantile(0.25)
Q3 = grouped_year1['Cost of Win Share'].quantile(0.75)
IQR = Q3 - Q1  # Interquartile Range

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers from the DataFrame
filtered_df = grouped_year1[(grouped_year1['Cost of Win Share'] >= lower_bound) & 
                             (grouped_year1['Cost of Win Share'] <= upper_bound)]

std_cost = filtered_df['Cost of Win Share'].std()

# %%
std_cost
# Out:
# 1.8479760346033192

# %%
cost_win_share_modeled
# Out:
# 3.81262326578587

# %% [markdown]
# The following code creates a function to grade the GM performance by signings. It also creates a z score for each GM's performance so it can be aggregated later in the GM holistic scores.

# %%
# Define a grading function
def assign_grade(cost):
    if cost < 0:
        return 'F'
    elif cost >= cost_win_share_modeled - std_cost * 0.5 and cost <= cost_win_share_modeled + std_cost * 0.5:
        return 'C'
    elif cost > cost_win_share_modeled - std_cost and cost <= cost_win_share_modeled - std_cost * 0.5:
        return 'B'
    elif cost < cost_win_share_modeled - std_cost:
        return 'A'
    elif cost > cost_win_share_modeled + std_cost * 0.5 and cost <= cost_win_share_modeled + std_cost * 2:
        return 'D'
    elif cost > cost_win_share_modeled + std_cost * 2:
        return 'F'

# Apply the grading function to the 'Cost of Win Share' column and create a new 'Grade' column
grouped_year1['Grade'] = grouped_year1['Cost of Win Share'].apply(assign_grade)

# %%
# Calculate the mean and standard deviation of the 'GM_Pct Change' column
mean_gm_pct_change = grouped_year1['Win Shares per Million'].mean()
std_gm_pct_change = grouped_year1['Win Shares per Million'].std()

# Create the 'z score' column by applying the Z-score formula
grouped_year1['z score'] = (grouped_year1['Win Shares per Million'] - mean_gm_pct_change) / std_gm_pct_change

# %%
grouped_year1.sort_values(by='Win Shares per Million', ascending = False)
# Out:
#          Acquiring GM Team Acquiring  AAV_sum  \
# 25         Sam Presti            OKC     2.00
# 9         James Jones            PHO    26.10
# 13       Justin Zanik            UTA    13.57
# 6        Calvin Booth            DEN    23.40
# 16          Leon Rose            NYK    13.80
# 8         Daryl Morey            PHI    31.22
# 27         Sean Marks            BRK    30.53
# 33       Will Dawkins            WAS    10.90
# 24        Rob Pelinka            LAL    69.00
# 12          Jon Horst            MIL    27.24
# 18     Michael Winger            LAC    17.95
# 19  Mike Dunleavy Jr.            GSW    19.30
# 2           Bob Myers            GSW    13.91
# 0       Andy Elisburg            MIA    48.62
# 26        Scott Perry            NYK    63.60
# 15      Landry Fields            ATL     6.50
# 11       John Hammond            ORL     2.91
# 14        Koby Altman            CLE    55.33
# 17      Marc Eversley            CHI    74.59
# 1      Anthony Parker            ORL    11.00
# 30     Trajan Langdon            NOP    18.75
# 22      Nico Harrison            DAL    47.40
# 21       Monte McNair            SAC    30.24
# 31     Travis Schlenk            ATL     5.84
# 23       Rafael Stone            HOU    86.99
# 34       Zach Kleiman            MEM     2.40
# 5        Brian Wright            SAS    31.30
# 28       Tim Connelly            MIN    12.10
# 4        Brad Stevens            BOS    29.90
# 10         Joe Cronin            POR    19.49
# 7       Chad Buchanan            IND    34.08
# 32        Troy Weaver            DET    15.20
# 29     Tommy Sheppard            WAS    21.85
# 20      Mitch Kupchak            CHO    21.52
# 3       Bobby Webster            TOR    29.89
#
#     Acquired Player Win Shares Year 1  Count  Cost of Win Share  \
# 25                                3.8      1           0.526316
# 9                                18.4     10           1.418478
# 13                                8.5      4           1.596471
# 6                                13.5      6           1.733333
# 16                                6.5      2           2.123077
# 8                                14.1      9           2.214184
# 27                               13.0     13           2.348462
# 33                                4.5      2           2.422222
# 24                               28.4     24           2.429577
# 12                               10.3      7           2.644660
# 18                                6.4      3           2.804688
# 19                                6.6      4           2.924242
# 2                                 4.6      4           3.023913
# 0                                15.4      5           3.157143
# 26                               18.8      5           3.382979
# 15                                1.8      3           3.611111
# 11                                0.8      1           3.637500
# 14                               14.8      9           3.738514
# 17                               19.8     10           3.767172
# 1                                 2.6      1           4.230769
# 30                                4.4      3           4.261364
# 22                               11.0      9           4.309091
# 21                                6.6      8           4.581818
# 31                                1.2      2           4.866667
# 23                               16.9      6           5.147337
# 34                                0.4      1           6.000000
# 5                                 4.9      6           6.387755
# 28                                1.7      4           7.117647
# 4                                 4.2     10           7.119048
# 10                                2.7      7           7.218519
# 7                                 4.7      5           7.251064
# 32                                1.6      2           9.500000
# 29                                1.7      2          12.852941
# 20                               -0.2      5        -107.600000
# 3                                -0.5      8         -59.780000
#
#     Win Shares per Million Grade   z score
# 25                1.900000     A  4.934350
# 9                 0.704981     A  1.185730
# 13                0.626382     A  0.939175
# 6                 0.576923     A  0.784030
# 16                0.471014     B  0.451808
# 8                 0.451634     B  0.391013
# 27                0.425811     B  0.310010
# 33                0.412844     B  0.269335
# 24                0.411594     B  0.265414
# 12                0.378120     B  0.160412
# 18                0.356546     B  0.092735
# 19                0.341969     C  0.047009
# 2                 0.330697     C  0.011652
# 0                 0.316742     C -0.032124
# 26                0.295597     C -0.098452
# 15                0.276923     C -0.157031
# 11                0.274914     C -0.163333
# 14                0.267486     C -0.186634
# 17                0.265451     C -0.193017
# 1                 0.236364     C -0.284261
# 30                0.234667     C -0.289584
# 22                0.232068     C -0.297737
# 21                0.218254     C -0.341069
# 31                0.205479     D -0.381141
# 23                0.194275     D -0.416287
# 34                0.166667     D -0.502891
# 5                 0.156550     D -0.534628
# 28                0.140496     D -0.584986
# 4                 0.140468     D -0.585072
# 10                0.138533     D -0.591144
# 7                 0.137911     D -0.593095
# 32                0.105263     F -0.695506
# 29                0.077803     F -0.781645
# 20               -0.009294     F -1.054856
# 3                -0.016728     F -1.078177

# %%
grouped_year1.to_csv('../outputs/signings_gm_z_scores_2022_2024.csv', index=False)

# %%
sns.scatterplot(data=filtered_df, x="AAV_sum", y="Cost of Win Share")
# Out:
# <Axes: xlabel='AAV_sum', ylabel='Cost of Win Share'>

# %%
filtered_df["AAV_sum"].corr(filtered_df["Cost of Win Share"])
# Out:
# 0.059085998177396036

# %% [markdown]
# ### Ratio of Players Signed to Players Lost

# %% [markdown]
# The following section is not used for the GM holistic scores at the end but gives another perspective at evaluating GM performance in free agency.

# %%
signings_df.columns
# Out:
# Index(['Season', 'Team Acquiring', 'Acquired Player', 'Team Losing',
#        'Acquisition Type', 'Acquiring GM', 'Losing GM', 'Year 2', 'Helper',
#        'AAV', 'One Year?', 'Acquired Player Win Shares Year 1',
#        'Acquired Player Win Shares Year 2'],
#       dtype='object')

# %%
filtered_df = signings_df.copy()

# Convert 'AAV' and 'Acquired Player BPM/WARP Year 1' to numeric, coercing errors to NaN
filtered_df['AAV'] = pd.to_numeric(filtered_df['AAV'], errors='coerce')
filtered_df['Acquired Player Win Shares Year 1'] = pd.to_numeric(filtered_df['Acquired Player Win Shares Year 1'], errors='coerce')

# Group by 'Team Acquiring' and calculate the sum of 'AAV' and 'Acquired Player BPM/WARP Year 1'
grouped_against = filtered_df.groupby('Losing GM').agg({
    'AAV': 'sum',
    'Acquired Player Win Shares Year 1': 'sum'
})

# Calculate the ratio of AAV to Acquired Player BPM/WARP Year 1
grouped_against['Cost of Win Share'] = grouped_against['AAV'] / grouped_against['Acquired Player Win Shares Year 1']

# Reset index for easier plotting
grouped_against = grouped_against.reset_index()

# %%
grouped_against
# Out:
#             Losing GM    AAV  Acquired Player Win Shares Year 1  \
# 0       Andy Elisburg  58.98                               13.3
# 1      Anthony Parker   2.50                                1.6
# 2           Bob Myers  16.44                                0.9
# 3       Bobby Webster  83.54                               19.7
# 4        Brad Stevens  44.25                                6.9
# 5        Brian Wright  54.05                               17.8
# 6        Calvin Booth  57.50                               16.6
# 7       Chad Buchanan  18.65                                4.1
# 8         Daryl Morey  29.82                               13.0
# 9         James Jones  26.46                                9.1
# 10         Joe Cronin  22.85                               10.2
# 11       John Hammond   9.10                                0.6
# 12          Jon Horst  27.99                                8.7
# 13       Justin Zanik  22.42                                5.7
# 14        Koby Altman  20.45                                6.4
# 15      Landry Fields  20.10                                3.7
# 16          Leon Rose   2.40                                0.4
# 17      Marc Eversley  40.51                               11.3
# 18     Michael Winger  12.27                                4.3
# 19  Mike Dunleavy Jr.  29.30                               10.1
# 20      Mitch Kupchak  24.26                                9.8
# 21       Monte McNair  17.09                               10.4
# 22      Nico Harrison  43.21                               12.9
# 23       Rafael Stone  23.30                                2.7
# 24        Rob Pelinka  54.15                               15.5
# 25       Sachin Gupta   2.64                                0.5
# 26         Sam Presti   6.80                                1.2
# 27        Scott Perry  17.59                                4.7
# 28         Sean Marks  63.92                               16.5
# 29       Tim Connelly   7.00                                4.7
# 30     Tommy Sheppard  12.83                                1.7
# 31     Trajan Langdon  31.94                                8.7
# 32     Travis Schlenk   2.64                                0.1
# 33       Trent Redden   2.50                                2.5
# 34        Troy Weaver  11.97                                2.6
# 35       Will Dawkins   4.10                                5.3
# 36       Zach Kleiman  24.00                                3.3
#
#     Cost of Win Share
# 0            4.434586
# 1            1.562500
# 2           18.266667
# 3            4.240609
# 4            6.413043
# 5            3.036517
# 6            3.463855
# 7            4.548780
# 8            2.293846
# 9            2.907692
# 10           2.240196
# 11          15.166667
# 12           3.217241
# 13           3.933333
# 14           3.195312
# 15           5.432432
# 16           6.000000
# 17           3.584956
# 18           2.853488
# 19           2.900990
# 20           2.475510
# 21           1.643269
# 22           3.349612
# 23           8.629630
# 24           3.493548
# 25           5.280000
# 26           5.666667
# 27           3.742553
# 28           3.873939
# 29           1.489362
# 30           7.547059
# 31           3.671264
# 32          26.400000
# 33           1.000000
# 34           4.603846
# 35           0.773585
# 36           7.272727

# %%
signings_df[signings_df['Losing GM'] == 'Rob Pelinka']
# Out:
#     Season Team Acquiring   Acquired Player Team Losing Acquisition Type  \
# 0     2022            PHI    Andre Drummond         LAL          Signing
# 6     2022            POR      Ben McLemore         LAL          Signing
# 8     2022            MIA   Markieff Morris         LAL          Signing
# 14    2022            BOS   Dennis Schroder         LAL          Signing
# 37    2024            MIL     Malik Beasley         LAL          Signing
# 43    2024            MIN        Troy Brown         LAL          Signing
# 44    2024            PHI          Mo Bamba         LAL          Signing
# 46    2024            BRK  Lonnie Walker IV         LAL          Signing
# 57    2022            CHI       Alex Caruso         LAL          Signing
# 64    2023            SAC        Malik Monk         LAL          Signing
# 76    2024            TOR   Dennis Schroder         LAL          Signing
#
#      Acquiring GM    Losing GM  Year 2                Helper    AAV One Year?  \
# 0     Daryl Morey  Rob Pelinka    2023    2022Andre Drummond   2.40       Yes
# 6      Joe Cronin  Rob Pelinka    2023      2022Ben McLemore   2.40       Yes
# 8   Andy Elisburg  Rob Pelinka    2023   2022Markieff Morris   2.60       Yes
# 14   Brad Stevens  Rob Pelinka    2023   2022Dennis Schroder   5.90       Yes
# 37      Jon Horst  Rob Pelinka    2025     2024Malik Beasley   2.70       Yes
# 43   Tim Connelly  Rob Pelinka    2025        2024Troy Brown   1.90       Yes
# 44    Daryl Morey  Rob Pelinka    2025          2024Mo Bamba   1.90       Yes
# 46     Sean Marks  Rob Pelinka    2025  2024Lonnie Walker IV   2.40       Yes
# 57  Marc Eversley  Rob Pelinka    2023       2022Alex Caruso   9.25        No
# 64   Monte McNair  Rob Pelinka    2024        2023Malik Monk   9.70        No
# 76  Bobby Webster  Rob Pelinka    2025   2024Dennis Schroder  13.00        No
#
#     Acquired Player Win Shares Year 1 Acquired Player Win Shares Year 2
# 0                                 2.9                               NaN
# 6                                 0.8                               NaN
# 8                                 0.3                               NaN
# 14                                NaN                               NaN
# 37                                3.5                               NaN
# 43                                NaN                               NaN
# 44                                2.0                               NaN
# 46                                0.8                               NaN
# 57                                2.0                               3.6
# 64                                3.2                               3.5
# 76                                NaN                               NaN

# %%
# Merge the two DataFrames on 'Team Acquiring' and 'Team Losing'
grouped_difference = pd.merge(grouped_year1, grouped_against, 
                              left_on='Acquiring GM', right_on='Losing GM', 
                              suffixes=('_acquired', '_losing'))

# Calculate the final ratio by dividing the AAV_to_WS of acquired over the AAV_to_WS of losing
grouped_difference['final_ratio'] = grouped_difference['Cost of Win Share_losing'] / grouped_difference['Cost of Win Share_acquired']

# Select only the relevant columns for the result
grouped_difference = grouped_difference[['Team Acquiring','Acquiring GM', 'final_ratio']]

# %% [markdown]
# In interpreting these values, above a ratio above 1 means that a team is more efficient with the players they bring in versus the players they lose.

# %%
# Set up the plot size with reduced height
plt.figure(figsize=(10, 10))  # Adjust the height here

# Create a horizontal bar chart using seaborn
sns.barplot(y='Acquiring GM', x='final_ratio', data=grouped_difference, color='gray')

# Add labels and title
plt.title('Cost of Win Share Lost Divided by Cost of Win Share Acquired')
plt.xlabel('Cost of Win Shares - Lost/Acquired Ratio')
plt.ylabel('Acquiring GM')

# Set the x-axis limits to show only positive values
plt.xlim(0, plt.xlim()[1])  # Lower limit is set to 0, upper limit remains unchanged

# Set the y-axis limits to keep bars within a certain height
plt.ylim(-0.5, len(grouped_difference) - 0.5)  # Adjust y-axis limits to fit the number of bars

# Add a black reference line for the modeled cost of a win share
plt.axvline(x=1, color='black', linestyle='--')

# Add an annotation with a multi-line text box aligned to the far right
plt.text(
    x=plt.xlim()[1] * 0.98,  # Position near the far right of the x-axis
    y=len(grouped_difference) * 0.2,  # Adjusted vertical position
    s="If number is above 1,\nthe GM is acquiring value more \nefficiently than he is losing\nIf number is below 1,\nthe GM is acquiring value less \nefficiently than he is losing",
    ha='right',  # Align text to the right
    va='top',  # Vertical alignment to the top
    color='black',
    fontsize=10,
    bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white", linewidth=0.5, alpha=0.9),
)

# Add larger team logos to the right of each bar
for i, (index, row) in enumerate(grouped_difference.iterrows()):
    team_name = row['Team Acquiring']  # Assuming 'Team Acquiring' has the team names
    logo_path = f'../logos/{team_name}.png'  # Update with actual path to logos
    
    # Load the logo image
    img = Image.open(logo_path)
    
    # Resize the image (width, height) - 100% larger than previous size
    img = img.resize((90, 44), Image.ANTIALIAS)  # Increased size to 90x44
    img = mpimg.imread(logo_path)  # Convert back to numpy array after resizing
    
    # Set the position for the logo to the right of each bar
    plt.imshow(img, aspect='auto', extent=[row['final_ratio'] + 0.1, row['final_ratio'] + 0.7, 
                                            i - 0.4, i + 0.4], zorder=5)

# Align y-axis labels with bars by setting the ticks and labels manually
plt.yticks(ticks=range(len(grouped_difference)), labels=grouped_difference['Acquiring GM'], rotation=0)

# Add a legend for the reference line
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_11500\2406756112.py:42: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((90, 44), Image.ANTIALIAS)  # Increased size to 90x44
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
grouped_difference[grouped_difference['Acquiring GM'] == 'Jon Horst']
# Out:
#    Team Acquiring Acquiring GM  final_ratio
# 12            MIL    Jon Horst     1.216505

# %%
grouped_year1[grouped_year1['Acquiring GM'] == 'Jon Horst']
# Out:
#    Acquiring GM Team Acquiring  AAV_sum  Acquired Player Win Shares Year 1  \
# 12    Jon Horst            MIL    27.24                               10.3
#
#     Count  Cost of Win Share Grade
# 12      7            2.64466     B

# %%
grouped_against[grouped_against['Losing GM'] == 'Jon Horst']
# Out:
#     Losing GM    AAV  Acquired Player Win Shares Year 1  Cost of Win Share
# 12  Jon Horst  27.99                                8.7           3.217241

# %% [markdown]
# Using Jon Horst as a way to validate this final ratio with the cost of win shares acquired and lost in respective tables.

# %%
grouped_difference.to_csv('./first year lost win shares divided by acquired win shares GM aggregation.csv')
