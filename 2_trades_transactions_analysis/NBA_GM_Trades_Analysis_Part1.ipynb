# %% [markdown]
# ## NBA GM Trades Analysis - Part 1 Data Cleaning

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import requests
import time
import json
from bs4 import BeautifulSoup

# %%
pd.set_option('display.max_columns', None)

# %%
years = list(range(2022,2025))

# %%
winshares_df = pd.read_csv('../inputs/win_shares_stats_2022-2024.csv')

# %%
trades_df = pd.read_csv('../inputs/NBA_GM_Transaction_Dataset_ALL_TEAMS_Trade_Data_2022-2024.csv')

# %% [markdown]
# ### Merging Data

# %%
merged_df = pd.merge(trades_df, winshares_df[['Player', 'Year', 'Tm', 'WS']], 
                     left_on=['Acquired Player', 'Season', 'Team Acquiring'], 
                     right_on=['Player', 'Year', 'Tm'], 
                     how='left')

# %%
# Assign the WS values to Acquired Player BPM/WARP Year 1 column
trades_df['Acquired Player Win Shares Year 1'] = merged_df['WS']

# %%
trades_df[trades_df['Acquired Player'] == 'James Harden']
# Out:
#      Season Team Acquiring Acquired Player Team Losing Acquisition Type  \
# 106    2022            PHI    James Harden         BRK            Trade
# 204    2024            LAC    James Harden         PHI            Trade
#
#      Acquiring GM    Losing GM  Year 2            Helper   AAV  \
# 106   Daryl Morey   Sean Marks    2023  2022James Harden  44.3
# 204  Trent Redden  Daryl Morey    2025  2024James Harden  35.6
#
#     Acquired Player Win Shares Year 1
# 106                               3.3
# 204                               8.4

# %%
winshares_df[winshares_df['Player'] == 'James Harden']
# Out:
#             Player Pos Age   Tm   G    MP   PER   TS%  3PAr   FTr ORB%  DRB%  \
# 292   James Harden  PG  32  TOT  65  2420  20.9  .583  .452  .540  2.6  19.7
# 293   James Harden  PG  32  BRK  44  1627  20.4  .576  .435  .496  2.9  20.2
# 294   James Harden  PG  32  PHI  21   792  21.8  .601  .493  .650  1.9  18.9
# 1096  James Harden  PG  33  PHI  58  2135  21.6  .607  .496  .429  2.3  17.1
# 1824  James Harden  PG  34  LAC  72  2470  18.6  .612  .594  .418  1.6  14.8
#
#       TRB%  AST% STL% BLK%  TOV%  USG%  OWS  DWS   WS WS/48 OBPM DBPM  BPM  \
# 292   11.3  40.3  1.7  1.3  18.8  27.2  4.9  2.7  7.6  .152  3.7  0.3  4.0
# 293   11.7  39.7  1.7  1.7  19.8  28.3  2.6  1.8  4.4  .130  3.7  0.4  4.1
# 294   10.5  41.4  1.6  0.6  16.4  24.9  2.3  0.9  3.3  .197  3.8  0.1  3.8
# 1096   9.8  43.3  1.6  1.4  16.3  25.0  5.8  2.6  8.4  .188  5.1  0.3  5.4
# 1824   8.4  33.6  1.5  2.1  16.0  20.6  5.9  2.5  8.4  .163  3.8  0.3  4.1
#
#      VORP  Year
# 292   3.7  2022
# 293   2.5  2022
# 294   1.2  2022
# 1096  4.0  2023
# 1824  3.8  2024

# %%
merged_df_year2 = pd.merge(trades_df, winshares_df[['Player', 'Year', 'Tm', 'WS']], 
                     left_on=['Acquired Player', 'Year 2', 'Team Acquiring'], 
                     right_on=['Player', 'Year', 'Tm'], 
                     how='left')

# %%
trades_df['Acquired Player Win Shares Year 2'] = merged_df_year2['WS']

# %% [markdown]
# The resulting dataset is all players acquired by trade from 2022-2024 and their performance in the subsequent seasons.

# %%
trades_df.isna().sum()
# Out:
# Season                                 0
# Team Acquiring                         0
# Acquired Player                        0
# Team Losing                            0
# Acquisition Type                       0
# Acquiring GM                           0
# Losing GM                              0
# Year 2                                 0
# Helper                                 0
# AAV                                    6
# Acquired Player Win Shares Year 1     83
# Acquired Player Win Shares Year 2    151
# dtype: int64

# %%
trades_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Season                             234 non-null    int64
#  1   Team Acquiring                     234 non-null    object
#  2   Acquired Player                    234 non-null    object
#  3   Team Losing                        234 non-null    object
#  4   Acquisition Type                   234 non-null    object
#  5   Acquiring GM                       234 non-null    object
#  6   Losing GM                          234 non-null    object
#  7   Year 2                             234 non-null    int64
#  8   Helper                             234 non-null    object
#  9   AAV                                228 non-null    float64
#  10  Acquired Player Win Shares Year 1  151 non-null    object
#  11  Acquired Player Win Shares Year 2  83 non-null     object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 22.1+ KB

# %% [markdown]
# From here it looks most players (151/234) in this dataset did not stay on the same team in year 2 after the acquisition.

# %%
trades_df[trades_df['Acquired Player Win Shares Year 2'].notna()]
# Out:
#      Season Team Acquiring Acquired Player Team Losing Acquisition Type  \
# 0      2022            BOS      Al Horford         OKC            Trade
# 2      2022            LAC   Jason Preston         ORL            Trade
# 5      2022            CHO       Kai Jones         NYK            Trade
# 7      2022            NYK  Quentin Grimes         LAC            Trade
# 8      2022            NYK   Miles McBride         OKC            Trade
# ..      ...            ...             ...         ...              ...
# 190    2023            IND    Jordan Nwora         MIL            Trade
# 191    2023            MIL     Jae Crowder         PHO            Trade
# 192    2023            PHO    Kevin Durant         BRK            Trade
# 195    2023            NYK       Josh Hart         POR            Trade
# 197    2023            LAC    Bones Hyland         DEN            Trade
#
#        Acquiring GM       Losing GM  Year 2              Helper   AAV  \
# 0      Brad Stevens      Sam Presti    2023      2022Al Horford  26.5
# 2    Michael Winger    John Hammond    2023   2022Jason Preston   1.0
# 5     Mitch Kupchak     Scott Perry    2023       2022Kai Jones   2.9
# 7       Scott Perry  Michael Winger    2023  2022Quentin Grimes   2.2
# 8       Scott Perry      Sam Presti    2023   2022Miles McBride   1.1
# ..              ...             ...     ...                 ...   ...
# 190   Chad Buchanan       Jon Horst    2024    2023Jordan Nwora   1.7
# 191       Jon Horst     James Jones    2024     2023Jae Crowder  10.1
# 192     James Jones      Sean Marks    2024    2023Kevin Durant  47.6
# 195     Scott Perry      Joe Cronin    2024       2023Josh Hart  12.9
# 197  Michael Winger    Calvin Booth    2024    2023Bones Hyland   2.3
#
#     Acquired Player Win Shares Year 1 Acquired Player Win Shares Year 2
# 0                                 7.6                               6.3
# 2                                 NaN                               0.1
# 5                                 0.0                               0.7
# 7                                 1.4                               4.8
# 8                                 0.2                               0.7
# ..                                ...                               ...
# 190                               0.8                               0.1
# 191                               1.2                               1.6
# 192                               1.1                               8.3
# 195                               2.8                               5.7
# 197                               0.5                               0.0
#
# [83 rows x 12 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
trades_df[trades_df['Acquired Player Win Shares Year 1'].isna()].sort_values('AAV', ascending=False)
# Out:
#      Season Team Acquiring           Acquired Player Team Losing  \
# 111    2022            WAS        Kristaps Porziņģis         DAL
# 105    2022            BRK               Ben Simmons         PHI
# 18     2022            TOR              Goran Dragic         MIA
# 152    2023            DET          Bojan Bogdanović         UTA
# 218    2024            CHO             Dāvis Bertāns         OKC
# 85     2022            IND               Ricky Rubio         CLE
# 109    2022            DAL             Davis Bertans         WAS
# 33     2022            NOP         Jonas Valanciunas         MEM
# 219    2024            DAL          P. J. Washington         CHO
# 53     2022            MEM          Patrick Beverley         LAC
# 212    2024            HOU              Steven Adams         MEM
# 206    2024            LAC              P. J. Tucker         PHI
# 50     2022            SAS           Al-Farouq Aminu         CHI
# 157    2023            HOU            Derrick Favors         OKC
# 203    2024            HOU            Victor Oladipo         OKC
# 142    2023            DET              Kemba Walker         NYK
# 1      2022            OKC              Kemba Walker         BOS
# 141    2023            WAS              Monté Morris         DEN
# 13     2022            MIN             Tauren Prince         CLE
# 100    2022            HOU           Dennis Schröder         BOS
# 76     2022            ATL             Kevin Knox II         NYK
# 210    2024            IND            Kira Lewis Jr.         NOP
# 230    2024            IND            Furkan Korkmaz         PHI
# 128    2023            SAS              Goran Dragić         TOR
# 215    2024            BRK           Dennis Schröder         TOR
# 68     2022            MEM                 Kris Dunn         BOS
# 41     2022            BOS                 Kris Dunn         ATL
# 31     2022            MEM              Eric Bledsoe         NOP
# 127    2023            HOU          Boban Marjanović         DAL
# 97     2022            POR          Tomas Satoransky         NOP
# 47     2022            NOP          Tomas Satoransky         CHI
# 95     2022            POR  Nickeil Alexander-Walker         NOP
# 135    2023            ATL          Maurice Harkless         SAC
# 185    2023            POR             Kevin Knox II         DET
# 156    2023            OKC          Maurice Harkless         ATL
# 115    2022            SAS              Goran Dragić         TOR
# 193    2023            PHO              T. J. Warren         BRK
# 189    2023            IND               Serge Ibaka         MIL
# 64     2022            DET            DeAndre Jordan         BRK
# 101    2022            HOU       Enes Kanter Freedom         BOS
# 66     2022            MEM                Marc Gasol         LAL
# 161    2023            OKC                Trey Burke         HOU
# 77     2022            NYK              Solomon Hill         ATL
# 125    2023            HOU                Trey Burke         DAL
# 57     2022            MEM       Juancho Hernangómez         MIN
# 67     2022            BOS       Juancho Hernangómez         MEM
# 126    2023            HOU           Marquese Chriss         DAL
# 79     2022            BOS                   Bol Bol         DEN
# 166    2023            IND              Nik Stauskas         BOS
# 160    2023            OKC            Sterling Brown         HOU
# 124    2023            HOU            Sterling Brown         DAL
# 80     2022            BOS                 PJ Dozier         DEN
# 227    2024            BRK            Jordan Goodwin         PHO
# 159    2023            HOU              Théo Maledon         OKC
# 213    2024            BOS            Xavier Tillman         MEM
# 194    2023            CHO     Sviatoslav Mykhailiuk         NYK
# 54     2022            MEM               Rajon Rondo         LAC
# 62     2022            BRK           Sekou Doumbouya         DET
# 98     2022            OKC                 KZ Okpala         MIA
# 74     2022            NYK          Denzel Valentine         CLE
# 29     2022            CHO                Wes Iwundu         NOP
# 63     2022            BRK             Jahlil Okafor         DET
# 75     2022            OKC                  Miye Oni         UTA
# 153    2023            UTA                 Saben Lee         DET
# 69     2022            MEM            Carsen Edwards         BOS
# 155    2023            ATL                Vít Krejčí         OKC
# 71     2022            BRK             Edmond Sumner         IND
# 164    2023            IND              Juwan Morgan         BOS
# 147    2023            UTA           Stanley Johnson         LAL
# 163    2023            IND               Malik Fitts         BOS
# 133    2023            ATL              Jock Landale         SAS
# 158    2023            HOU                 Ty Jerome         OKC
# 4      2022            IND               Isaiah Todd         MIL
# 205    2024            LAC            Filip Petrušev         PHI
# 207    2024            SAC            Filip Petrušev         LAC
# 23     2022            SAS        Chandler Hutchison         WAS
# 2      2022            LAC             Jason Preston         ORL
# 233    2024            SAS         Marcus Morris Sr.         PHI
# 65     2022            LAL               Wang Zhelin         MEM
# 70     2022            BRK       Cash considerations         HOU
# 73     2022            LAL            Louis Labeyrie         CLE
# 130    2023            MIL               Hugo Besson         IND
# 223    2024            MIL       Dimitrios Agravanis         SAC
#
#     Acquisition Type    Acquiring GM       Losing GM  Year 2  \
# 111            Trade  Tommy Sheppard   Nico Harrison    2023
# 105            Trade      Sean Marks     Daryl Morey    2023
# 18             Trade   Bobby Webster   Andy Elisburg    2023
# 152            Trade     Troy Weaver    Justin Zanik    2024
# 218            Trade   Mitch Kupchak      Sam Presti    2025
# 85             Trade   Chad Buchanan     Koby Altman    2023
# 109            Trade   Nico Harrison  Tommy Sheppard    2023
# 33             Trade  Trajan Langdon    Zach Kleiman    2023
# 219            Trade   Nico Harrison   Mitch Kupchak    2025
# 53             Trade    Zach Kleiman  Michael Winger    2023
# 212            Trade    Rafael Stone    Zach Kleiman    2025
# 206            Trade    Trent Redden     Daryl Morey    2025
# 50             Trade    Brian Wright   Marc Eversley    2023
# 157            Trade    Rafael Stone      Sam Presti    2024
# 203            Trade    Rafael Stone      Sam Presti    2025
# 142            Trade     Troy Weaver     Scott Perry    2024
# 1              Trade      Sam Presti    Brad Stevens    2023
# 141            Trade    Will Dawkins    Calvin Booth    2024
# 13             Trade    Sachin Gupta     Koby Altman    2023
# 100            Trade    Rafael Stone    Brad Stevens    2023
# 76             Trade  Travis Schlenk     Scott Perry    2023
# 210            Trade   Chad Buchanan  Trajan Langdon    2025
# 230            Trade   Chad Buchanan     Daryl Morey    2025
# 128            Trade    Brian Wright   Bobby Webster    2024
# 215            Trade      Sean Marks   Bobby Webster    2025
# 68             Trade    Zach Kleiman    Brad Stevens    2023
# 41             Trade    Brad Stevens  Travis Schlenk    2023
# 31             Trade    Zach Kleiman  Trajan Langdon    2023
# 127            Trade    Rafael Stone   Nico Harrison    2024
# 97             Trade      Joe Cronin  Trajan Langdon    2023
# 47             Trade  Trajan Langdon   Marc Eversley    2023
# 95             Trade      Joe Cronin  Trajan Langdon    2023
# 135            Trade   Landry Fields    Monte McNair    2024
# 185            Trade      Joe Cronin     Troy Weaver    2024
# 156            Trade      Sam Presti   Landry Fields    2024
# 115            Trade    Brian Wright   Bobby Webster    2023
# 193            Trade     James Jones      Sean Marks    2024
# 189            Trade   Chad Buchanan       Jon Horst    2024
# 64             Trade     Troy Weaver      Sean Marks    2023
# 101            Trade    Rafael Stone    Brad Stevens    2023
# 66             Trade    Zach Kleiman     Rob Pelinka    2023
# 161            Trade      Sam Presti    Rafael Stone    2024
# 77             Trade     Scott Perry  Travis Schlenk    2023
# 125            Trade    Rafael Stone   Nico Harrison    2024
# 57             Trade    Zach Kleiman    Sachin Gupta    2023
# 67             Trade    Brad Stevens    Zach Kleiman    2023
# 126            Trade    Rafael Stone   Nico Harrison    2024
# 79             Trade    Brad Stevens    Calvin Booth    2023
# 166            Trade   Chad Buchanan    Brad Stevens    2024
# 160            Trade      Sam Presti    Rafael Stone    2024
# 124            Trade    Rafael Stone   Nico Harrison    2024
# 80             Trade    Brad Stevens    Calvin Booth    2023
# 227            Trade      Sean Marks     James Jones    2025
# 159            Trade    Rafael Stone      Sam Presti    2024
# 213            Trade    Brad Stevens    Zach Kleiman    2025
# 194            Trade   Mitch Kupchak     Scott Perry    2024
# 54             Trade    Zach Kleiman  Michael Winger    2023
# 62             Trade      Sean Marks     Troy Weaver    2023
# 98             Trade      Sam Presti   Andy Elisburg    2023
# 74             Trade     Scott Perry     Koby Altman    2023
# 29             Trade   Mitch Kupchak  Trajan Langdon    2023
# 63             Trade      Sean Marks     Troy Weaver    2023
# 75             Trade      Sam Presti    Justin Zanik    2023
# 153            Trade    Justin Zanik     Troy Weaver    2024
# 69             Trade    Zach Kleiman    Brad Stevens    2023
# 155            Trade   Landry Fields      Sam Presti    2024
# 71             Trade      Sean Marks   Chad Buchanan    2023
# 164            Trade   Chad Buchanan    Brad Stevens    2024
# 147            Trade    Justin Zanik     Rob Pelinka    2024
# 163            Trade   Chad Buchanan    Brad Stevens    2024
# 133            Trade   Landry Fields    Brian Wright    2024
# 158            Trade    Rafael Stone      Sam Presti    2024
# 4              Trade   Chad Buchanan       Jon Horst    2023
# 205            Trade    Trent Redden     Daryl Morey    2025
# 207            Trade    Monte McNair    Trent Redden    2025
# 23             Trade    Brian Wright  Tommy Sheppard    2023
# 2              Trade  Michael Winger    John Hammond    2023
# 233            Trade    Brian Wright     Daryl Morey    2025
# 65             Trade     Rob Pelinka    Zach Kleiman    2023
# 70             Trade      Sean Marks    Rafael Stone    2023
# 73             Trade     Rob Pelinka     Koby Altman    2023
# 130            Trade       Jon Horst   Chad Buchanan    2024
# 223            Trade       Jon Horst    Monte McNair    2025
#
#                            Helper   AAV Acquired Player Win Shares Year 1  \
# 111        2022Kristaps Porziņģis  33.8                               NaN
# 105               2022Ben Simmons  33.0                               NaN
# 18               2022Goran Dragic  19.4                               NaN
# 152          2023Bojan Bogdanović  19.3                               NaN
# 218             2024Dāvis Bertāns  17.0                               NaN
# 85                2022Ricky Rubio  17.0                               NaN
# 109             2022Davis Bertans  16.0                               NaN
# 33          2022Jonas Valanciunas  14.7                               NaN
# 219          2024P. J. Washington  13.5                               NaN
# 53           2022Patrick Beverley  13.0                               NaN
# 212              2024Steven Adams  12.6                               NaN
# 206              2024P. J. Tucker  11.0                               NaN
# 50            2022Al-Farouq Aminu  10.2                               NaN
# 157            2023Derrick Favors  10.1                               NaN
# 203            2024Victor Oladipo   9.5                               NaN
# 142              2023Kemba Walker   9.2                               NaN
# 1                2022Kemba Walker   9.2                               NaN
# 141              2023Monté Morris   9.1                               NaN
# 13              2022Tauren Prince   7.3                               NaN
# 100           2022Dennis Schröder   5.9                               NaN
# 76              2022Kevin Knox II   5.8                               NaN
# 210            2024Kira Lewis Jr.   5.7                               NaN
# 230            2024Furkan Korkmaz   5.4                               NaN
# 128              2023Goran Dragić   4.7                               NaN
# 215           2024Dennis Schröder   4.7                               NaN
# 68                  2022Kris Dunn   4.0                               NaN
# 41                  2022Kris Dunn   4.0                               NaN
# 31               2022Eric Bledsoe   3.9                               NaN
# 127          2023Boban Marjanović   3.5                               NaN
# 97           2022Tomas Satoransky   3.3                               NaN
# 47           2022Tomas Satoransky   3.3                               NaN
# 95   2022Nickeil Alexander-Walker   3.2                               NaN
# 135          2023Maurice Harkless   3.0                               NaN
# 185             2023Kevin Knox II   3.0                               NaN
# 156          2023Maurice Harkless   3.0                               NaN
# 115              2022Goran Dragić   2.9                               NaN
# 193              2023T. J. Warren   2.9                               NaN
# 189               2023Serge Ibaka   2.9                               NaN
# 64             2022DeAndre Jordan   2.6                               NaN
# 101       2022Enes Kanter Freedom   2.6                               NaN
# 66                 2022Marc Gasol   2.6                               NaN
# 161                2023Trey Burke   2.4                               NaN
# 77               2022Solomon Hill   2.4                               NaN
# 125                2023Trey Burke   2.4                               NaN
# 57        2022Juancho Hernangómez   2.3                               NaN
# 67        2022Juancho Hernangómez   2.3                               NaN
# 126           2023Marquese Chriss   2.2                               NaN
# 79                    2022Bol Bol   2.2                               NaN
# 166              2023Nik Stauskas   2.0                               NaN
# 160            2023Sterling Brown   2.0                               NaN
# 124            2023Sterling Brown   2.0                               NaN
# 80                  2022PJ Dozier   2.0                               NaN
# 227            2024Jordan Goodwin   1.9                               NaN
# 159              2023Théo Maledon   1.9                               NaN
# 213            2024Xavier Tillman   1.9                               NaN
# 194     2023Sviatoslav Mykhailiuk   1.8                               NaN
# 54                2022Rajon Rondo   1.8                               NaN
# 62            2022Sekou Doumbouya   1.8                               NaN
# 98                  2022KZ Okpala   1.8                               NaN
# 74           2022Denzel Valentine   1.8                               NaN
# 29                 2022Wes Iwundu   1.7                               NaN
# 63              2022Jahlil Okafor   1.7                               NaN
# 75                   2022Miye Oni   1.7                               NaN
# 153                 2023Saben Lee   1.7                               NaN
# 69             2022Carsen Edwards   1.6                               NaN
# 155                2023Vít Krejčí   1.6                               NaN
# 71              2022Edmond Sumner   1.6                               NaN
# 164              2023Juwan Morgan   1.6                               NaN
# 147           2023Stanley Johnson   1.6                               NaN
# 163               2023Malik Fitts   1.5                               NaN
# 133              2023Jock Landale   1.5                               NaN
# 158                 2023Ty Jerome   1.5                               NaN
# 4                 2022Isaiah Todd   1.5                               NaN
# 205            2024Filip Petrušev   1.1                               NaN
# 207            2024Filip Petrušev   1.1                               NaN
# 23         2022Chandler Hutchison   1.1                               NaN
# 2               2022Jason Preston   1.0                               NaN
# 233         2024Marcus Morris Sr.   0.3                               NaN
# 65                2022Wang Zhelin   NaN                               NaN
# 70        2022Cash considerations   NaN                               NaN
# 73             2022Louis Labeyrie   NaN                               NaN
# 130               2023Hugo Besson   NaN                               NaN
# 223       2024Dimitrios Agravanis   NaN                               NaN
#
#     Acquired Player Win Shares Year 2
# 111                               NaN
# 105                               2.2
# 18                                NaN
# 152                               NaN
# 218                               NaN
# 85                                NaN
# 109                               NaN
# 33                                NaN
# 219                               NaN
# 53                                NaN
# 212                               NaN
# 206                               NaN
# 50                                NaN
# 157                               NaN
# 203                               NaN
# 142                               NaN
# 1                                 NaN
# 141                               NaN
# 13                                NaN
# 100                               NaN
# 76                                NaN
# 210                               NaN
# 230                               NaN
# 128                               NaN
# 215                               NaN
# 68                                NaN
# 41                                NaN
# 31                                NaN
# 127                               NaN
# 97                                NaN
# 47                                NaN
# 95                                NaN
# 135                               NaN
# 185                               NaN
# 156                               NaN
# 115                               NaN
# 193                               NaN
# 189                               NaN
# 64                                NaN
# 101                               NaN
# 66                                NaN
# 161                               NaN
# 77                                NaN
# 125                               NaN
# 57                                NaN
# 67                                NaN
# 126                               NaN
# 79                                NaN
# 166                               NaN
# 160                               NaN
# 124                               NaN
# 80                                NaN
# 227                               NaN
# 159                               NaN
# 213                               NaN
# 194                               NaN
# 54                                NaN
# 62                                NaN
# 98                                NaN
# 74                                NaN
# 29                                NaN
# 63                                NaN
# 75                                NaN
# 153                               NaN
# 69                                NaN
# 155                               NaN
# 71                                1.3
# 164                               NaN
# 147                               NaN
# 163                               NaN
# 133                               NaN
# 158                               NaN
# 4                                 NaN
# 205                               NaN
# 207                               NaN
# 23                                NaN
# 2                                 0.1
# 233                               NaN
# 65                                NaN
# 70                                NaN
# 73                                NaN
# 130                               NaN
# 223                               NaN

# %%
trades_df.loc[(trades_df['Acquired Player'] == 'Kristaps Porziņģis') & (trades_df['Season'] == 2022), 'Acquired Player Win Shares Year 1'] = 2.2
trades_df.loc[(trades_df['Acquired Player'] == 'Ben Simmons') & (trades_df['Season'] == 2022), 'Acquired Player Win Shares Year 1'] = 0
trades_df.loc[(trades_df['Acquired Player'] == 'Goran Dragic') & (trades_df['Season'] == 2022), 'Acquired Player Win Shares Year 1'] = 0.3
trades_df.loc[(trades_df['Acquired Player'] == 'Bojan Bogdanović') & (trades_df['Season'] == 2023), 'Acquired Player Win Shares Year 1'] = 3.5
trades_df.loc[(trades_df['Acquired Player'] == 'Dāvis Bertāns') & (trades_df['Season'] == 2024), 'Acquired Player Win Shares Year 1'] = 0.4
trades_df.loc[(trades_df['Acquired Player'] == 'Davis Bertans') & (trades_df['Season'] == 2022), 'Acquired Player Win Shares Year 1'] = 0.6
trades_df.loc[(trades_df['Acquired Player'] == 'Jonas Valanciunas') & (trades_df['Season'] == 2022), 'Acquired Player Win Shares Year 1'] = 7.3
trades_df.loc[(trades_df['Acquired Player'] == 'P. J. Washington') & (trades_df['Season'] == 2024), 'Acquired Player Win Shares Year 1'] = 1.1
trades_df.loc[(trades_df['Acquired Player'] == 'Ricky Rubio') & (trades_df['Season'] == 2022), 'Acquired Player Win Shares Year 1'] = 1.3

# %% [markdown]
# Because some players have missing data, I have filled in the win shares data for relevant players above.

# %%
trades_df = trades_df.dropna(subset=['AAV'])

# %%
trades_df[trades_df['Acquired Player Win Shares Year 1'].isna()].sort_values('AAV', ascending=False)
# Out:
#      Season Team Acquiring           Acquired Player Team Losing  \
# 53     2022            MEM          Patrick Beverley         LAC
# 212    2024            HOU              Steven Adams         MEM
# 206    2024            LAC              P. J. Tucker         PHI
# 50     2022            SAS           Al-Farouq Aminu         CHI
# 157    2023            HOU            Derrick Favors         OKC
# 203    2024            HOU            Victor Oladipo         OKC
# 142    2023            DET              Kemba Walker         NYK
# 1      2022            OKC              Kemba Walker         BOS
# 141    2023            WAS              Monté Morris         DEN
# 13     2022            MIN             Tauren Prince         CLE
# 100    2022            HOU           Dennis Schröder         BOS
# 76     2022            ATL             Kevin Knox II         NYK
# 210    2024            IND            Kira Lewis Jr.         NOP
# 230    2024            IND            Furkan Korkmaz         PHI
# 215    2024            BRK           Dennis Schröder         TOR
# 128    2023            SAS              Goran Dragić         TOR
# 41     2022            BOS                 Kris Dunn         ATL
# 68     2022            MEM                 Kris Dunn         BOS
# 31     2022            MEM              Eric Bledsoe         NOP
# 127    2023            HOU          Boban Marjanović         DAL
# 47     2022            NOP          Tomas Satoransky         CHI
# 97     2022            POR          Tomas Satoransky         NOP
# 95     2022            POR  Nickeil Alexander-Walker         NOP
# 156    2023            OKC          Maurice Harkless         ATL
# 185    2023            POR             Kevin Knox II         DET
# 135    2023            ATL          Maurice Harkless         SAC
# 115    2022            SAS              Goran Dragić         TOR
# 189    2023            IND               Serge Ibaka         MIL
# 193    2023            PHO              T. J. Warren         BRK
# 64     2022            DET            DeAndre Jordan         BRK
# 101    2022            HOU       Enes Kanter Freedom         BOS
# 66     2022            MEM                Marc Gasol         LAL
# 161    2023            OKC                Trey Burke         HOU
# 125    2023            HOU                Trey Burke         DAL
# 77     2022            NYK              Solomon Hill         ATL
# 67     2022            BOS       Juancho Hernangómez         MEM
# 57     2022            MEM       Juancho Hernangómez         MIN
# 79     2022            BOS                   Bol Bol         DEN
# 126    2023            HOU           Marquese Chriss         DAL
# 124    2023            HOU            Sterling Brown         DAL
# 166    2023            IND              Nik Stauskas         BOS
# 80     2022            BOS                 PJ Dozier         DEN
# 160    2023            OKC            Sterling Brown         HOU
# 227    2024            BRK            Jordan Goodwin         PHO
# 159    2023            HOU              Théo Maledon         OKC
# 213    2024            BOS            Xavier Tillman         MEM
# 194    2023            CHO     Sviatoslav Mykhailiuk         NYK
# 62     2022            BRK           Sekou Doumbouya         DET
# 54     2022            MEM               Rajon Rondo         LAC
# 74     2022            NYK          Denzel Valentine         CLE
# 98     2022            OKC                 KZ Okpala         MIA
# 75     2022            OKC                  Miye Oni         UTA
# 153    2023            UTA                 Saben Lee         DET
# 29     2022            CHO                Wes Iwundu         NOP
# 63     2022            BRK             Jahlil Okafor         DET
# 71     2022            BRK             Edmond Sumner         IND
# 69     2022            MEM            Carsen Edwards         BOS
# 164    2023            IND              Juwan Morgan         BOS
# 155    2023            ATL                Vít Krejčí         OKC
# 147    2023            UTA           Stanley Johnson         LAL
# 4      2022            IND               Isaiah Todd         MIL
# 158    2023            HOU                 Ty Jerome         OKC
# 133    2023            ATL              Jock Landale         SAS
# 163    2023            IND               Malik Fitts         BOS
# 205    2024            LAC            Filip Petrušev         PHI
# 207    2024            SAC            Filip Petrušev         LAC
# 23     2022            SAS        Chandler Hutchison         WAS
# 2      2022            LAC             Jason Preston         ORL
# 233    2024            SAS         Marcus Morris Sr.         PHI
#
#     Acquisition Type    Acquiring GM       Losing GM  Year 2  \
# 53             Trade    Zach Kleiman  Michael Winger    2023
# 212            Trade    Rafael Stone    Zach Kleiman    2025
# 206            Trade    Trent Redden     Daryl Morey    2025
# 50             Trade    Brian Wright   Marc Eversley    2023
# 157            Trade    Rafael Stone      Sam Presti    2024
# 203            Trade    Rafael Stone      Sam Presti    2025
# 142            Trade     Troy Weaver     Scott Perry    2024
# 1              Trade      Sam Presti    Brad Stevens    2023
# 141            Trade    Will Dawkins    Calvin Booth    2024
# 13             Trade    Sachin Gupta     Koby Altman    2023
# 100            Trade    Rafael Stone    Brad Stevens    2023
# 76             Trade  Travis Schlenk     Scott Perry    2023
# 210            Trade   Chad Buchanan  Trajan Langdon    2025
# 230            Trade   Chad Buchanan     Daryl Morey    2025
# 215            Trade      Sean Marks   Bobby Webster    2025
# 128            Trade    Brian Wright   Bobby Webster    2024
# 41             Trade    Brad Stevens  Travis Schlenk    2023
# 68             Trade    Zach Kleiman    Brad Stevens    2023
# 31             Trade    Zach Kleiman  Trajan Langdon    2023
# 127            Trade    Rafael Stone   Nico Harrison    2024
# 47             Trade  Trajan Langdon   Marc Eversley    2023
# 97             Trade      Joe Cronin  Trajan Langdon    2023
# 95             Trade      Joe Cronin  Trajan Langdon    2023
# 156            Trade      Sam Presti   Landry Fields    2024
# 185            Trade      Joe Cronin     Troy Weaver    2024
# 135            Trade   Landry Fields    Monte McNair    2024
# 115            Trade    Brian Wright   Bobby Webster    2023
# 189            Trade   Chad Buchanan       Jon Horst    2024
# 193            Trade     James Jones      Sean Marks    2024
# 64             Trade     Troy Weaver      Sean Marks    2023
# 101            Trade    Rafael Stone    Brad Stevens    2023
# 66             Trade    Zach Kleiman     Rob Pelinka    2023
# 161            Trade      Sam Presti    Rafael Stone    2024
# 125            Trade    Rafael Stone   Nico Harrison    2024
# 77             Trade     Scott Perry  Travis Schlenk    2023
# 67             Trade    Brad Stevens    Zach Kleiman    2023
# 57             Trade    Zach Kleiman    Sachin Gupta    2023
# 79             Trade    Brad Stevens    Calvin Booth    2023
# 126            Trade    Rafael Stone   Nico Harrison    2024
# 124            Trade    Rafael Stone   Nico Harrison    2024
# 166            Trade   Chad Buchanan    Brad Stevens    2024
# 80             Trade    Brad Stevens    Calvin Booth    2023
# 160            Trade      Sam Presti    Rafael Stone    2024
# 227            Trade      Sean Marks     James Jones    2025
# 159            Trade    Rafael Stone      Sam Presti    2024
# 213            Trade    Brad Stevens    Zach Kleiman    2025
# 194            Trade   Mitch Kupchak     Scott Perry    2024
# 62             Trade      Sean Marks     Troy Weaver    2023
# 54             Trade    Zach Kleiman  Michael Winger    2023
# 74             Trade     Scott Perry     Koby Altman    2023
# 98             Trade      Sam Presti   Andy Elisburg    2023
# 75             Trade      Sam Presti    Justin Zanik    2023
# 153            Trade    Justin Zanik     Troy Weaver    2024
# 29             Trade   Mitch Kupchak  Trajan Langdon    2023
# 63             Trade      Sean Marks     Troy Weaver    2023
# 71             Trade      Sean Marks   Chad Buchanan    2023
# 69             Trade    Zach Kleiman    Brad Stevens    2023
# 164            Trade   Chad Buchanan    Brad Stevens    2024
# 155            Trade   Landry Fields      Sam Presti    2024
# 147            Trade    Justin Zanik     Rob Pelinka    2024
# 4              Trade   Chad Buchanan       Jon Horst    2023
# 158            Trade    Rafael Stone      Sam Presti    2024
# 133            Trade   Landry Fields    Brian Wright    2024
# 163            Trade   Chad Buchanan    Brad Stevens    2024
# 205            Trade    Trent Redden     Daryl Morey    2025
# 207            Trade    Monte McNair    Trent Redden    2025
# 23             Trade    Brian Wright  Tommy Sheppard    2023
# 2              Trade  Michael Winger    John Hammond    2023
# 233            Trade    Brian Wright     Daryl Morey    2025
#
#                            Helper   AAV Acquired Player Win Shares Year 1  \
# 53           2022Patrick Beverley  13.0                               NaN
# 212              2024Steven Adams  12.6                               NaN
# 206              2024P. J. Tucker  11.0                               NaN
# 50            2022Al-Farouq Aminu  10.2                               NaN
# 157            2023Derrick Favors  10.1                               NaN
# 203            2024Victor Oladipo   9.5                               NaN
# 142              2023Kemba Walker   9.2                               NaN
# 1                2022Kemba Walker   9.2                               NaN
# 141              2023Monté Morris   9.1                               NaN
# 13              2022Tauren Prince   7.3                               NaN
# 100           2022Dennis Schröder   5.9                               NaN
# 76              2022Kevin Knox II   5.8                               NaN
# 210            2024Kira Lewis Jr.   5.7                               NaN
# 230            2024Furkan Korkmaz   5.4                               NaN
# 215           2024Dennis Schröder   4.7                               NaN
# 128              2023Goran Dragić   4.7                               NaN
# 41                  2022Kris Dunn   4.0                               NaN
# 68                  2022Kris Dunn   4.0                               NaN
# 31               2022Eric Bledsoe   3.9                               NaN
# 127          2023Boban Marjanović   3.5                               NaN
# 47           2022Tomas Satoransky   3.3                               NaN
# 97           2022Tomas Satoransky   3.3                               NaN
# 95   2022Nickeil Alexander-Walker   3.2                               NaN
# 156          2023Maurice Harkless   3.0                               NaN
# 185             2023Kevin Knox II   3.0                               NaN
# 135          2023Maurice Harkless   3.0                               NaN
# 115              2022Goran Dragić   2.9                               NaN
# 189               2023Serge Ibaka   2.9                               NaN
# 193              2023T. J. Warren   2.9                               NaN
# 64             2022DeAndre Jordan   2.6                               NaN
# 101       2022Enes Kanter Freedom   2.6                               NaN
# 66                 2022Marc Gasol   2.6                               NaN
# 161                2023Trey Burke   2.4                               NaN
# 125                2023Trey Burke   2.4                               NaN
# 77               2022Solomon Hill   2.4                               NaN
# 67        2022Juancho Hernangómez   2.3                               NaN
# 57        2022Juancho Hernangómez   2.3                               NaN
# 79                    2022Bol Bol   2.2                               NaN
# 126           2023Marquese Chriss   2.2                               NaN
# 124            2023Sterling Brown   2.0                               NaN
# 166              2023Nik Stauskas   2.0                               NaN
# 80                  2022PJ Dozier   2.0                               NaN
# 160            2023Sterling Brown   2.0                               NaN
# 227            2024Jordan Goodwin   1.9                               NaN
# 159              2023Théo Maledon   1.9                               NaN
# 213            2024Xavier Tillman   1.9                               NaN
# 194     2023Sviatoslav Mykhailiuk   1.8                               NaN
# 62            2022Sekou Doumbouya   1.8                               NaN
# 54                2022Rajon Rondo   1.8                               NaN
# 74           2022Denzel Valentine   1.8                               NaN
# 98                  2022KZ Okpala   1.8                               NaN
# 75                   2022Miye Oni   1.7                               NaN
# 153                 2023Saben Lee   1.7                               NaN
# 29                 2022Wes Iwundu   1.7                               NaN
# 63              2022Jahlil Okafor   1.7                               NaN
# 71              2022Edmond Sumner   1.6                               NaN
# 69             2022Carsen Edwards   1.6                               NaN
# 164              2023Juwan Morgan   1.6                               NaN
# 155                2023Vít Krejčí   1.6                               NaN
# 147           2023Stanley Johnson   1.6                               NaN
# 4                 2022Isaiah Todd   1.5                               NaN
# 158                 2023Ty Jerome   1.5                               NaN
# 133              2023Jock Landale   1.5                               NaN
# 163               2023Malik Fitts   1.5                               NaN
# 205            2024Filip Petrušev   1.1                               NaN
# 207            2024Filip Petrušev   1.1                               NaN
# 23         2022Chandler Hutchison   1.1                               NaN
# 2               2022Jason Preston   1.0                               NaN
# 233         2024Marcus Morris Sr.   0.3                               NaN
#
#     Acquired Player Win Shares Year 2
# 53                                NaN
# 212                               NaN
# 206                               NaN
# 50                                NaN
# 157                               NaN
# 203                               NaN
# 142                               NaN
# 1                                 NaN
# 141                               NaN
# 13                                NaN
# 100                               NaN
# 76                                NaN
# 210                               NaN
# 230                               NaN
# 215                               NaN
# 128                               NaN
# 41                                NaN
# 68                                NaN
# 31                                NaN
# 127                               NaN
# 47                                NaN
# 97                                NaN
# 95                                NaN
# 156                               NaN
# 185                               NaN
# 135                               NaN
# 115                               NaN
# 189                               NaN
# 193                               NaN
# 64                                NaN
# 101                               NaN
# 66                                NaN
# 161                               NaN
# 125                               NaN
# 77                                NaN
# 67                                NaN
# 57                                NaN
# 79                                NaN
# 126                               NaN
# 124                               NaN
# 166                               NaN
# 80                                NaN
# 160                               NaN
# 227                               NaN
# 159                               NaN
# 213                               NaN
# 194                               NaN
# 62                                NaN
# 54                                NaN
# 74                                NaN
# 98                                NaN
# 75                                NaN
# 153                               NaN
# 29                                NaN
# 63                                NaN
# 71                                1.3
# 69                                NaN
# 164                               NaN
# 155                               NaN
# 147                               NaN
# 4                                 NaN
# 158                               NaN
# 133                               NaN
# 163                               NaN
# 205                               NaN
# 207                               NaN
# 23                                NaN
# 2                                 0.1
# 233                               NaN

# %%
trades_df['Acquired Player Win Shares Year 1'] = trades_df['Acquired Player Win Shares Year 1'].fillna(0)

# %%
trades_df.to_csv('../outputs/trade_acquired_win_shares_2022-2024.csv', index=False)
