# %% [markdown]
# ## NBA GM Trades Analysis - Part 2 Analysis

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import requests
import time
import json
from bs4 import BeautifulSoup

# %%
pd.set_option('display.max_columns', None)

# %%
trades_df = pd.read_csv('C:/Users/kevin/Downloads/trade acquired win shares 2022-2024.csv')

# %% [markdown]
# ## Aggregation and Visualization

# %% [markdown]
# ### Cost per Win Share

# %%
# Convert 'AAV' and 'Acquired Player BPM/WARP Year 1' to numeric, coercing errors to NaN
trades_df['AAV'] = pd.to_numeric(trades_df['AAV'], errors='coerce')
trades_df['Acquired Player Win Shares Year 1'] = pd.to_numeric(trades_df['Acquired Player Win Shares Year 1'], errors='coerce')

# Group by 'Acquiring GM' and 'Team Acquiring', then calculate the sum and count
grouped_year1 = trades_df.groupby(['Acquiring GM', 'Team Acquiring']).agg({
    'AAV': 'sum',
    'Acquired Player Win Shares Year 1': 'sum',
    'Acquiring GM': 'count'  # Using 'count' to get the number of entries per group
})

# Rename the count column for clarity
grouped_year1 = grouped_year1.rename(columns={'Acquiring GM': 'Count'})

# Calculate the ratio of AAV to Acquired Player BPM/WARP Year 1
grouped_year1['Cost of Win Share'] = grouped_year1['AAV'] / grouped_year1['Acquired Player Win Shares Year 1']

# Reset index for easier plotting
grouped_year1 = grouped_year1.reset_index()

# %%
grouped_year1 = grouped_year1.rename(columns={'AAV': 'AAV_sum'})

# %%
filtered_df = trades_df.copy()

# Convert 'AAV' and 'Acquired Player BPM/WARP Year 1' to numeric, coercing errors to NaN
filtered_df['AAV'] = pd.to_numeric(filtered_df['AAV'], errors='coerce')
filtered_df['Acquired Player Win Shares Year 1'] = pd.to_numeric(filtered_df['Acquired Player Win Shares Year 1'], errors='coerce')

# Group by 'Team Acquiring' and calculate the sum of 'AAV' and 'Acquired Player BPM/WARP Year 1'
grouped_against = filtered_df.groupby('Losing GM').agg({
    'AAV': 'sum',
    'Acquired Player Win Shares Year 1': 'sum'
})

# Calculate the ratio of AAV to Acquired Player BPM/WARP Year 1
grouped_against['Cost of Win Share'] = grouped_against['AAV'] / grouped_against['Acquired Player Win Shares Year 1']

# Reset index for easier plotting
grouped_against = grouped_against.reset_index()

# %%
# Merge the two DataFrames on 'Team Acquiring' and 'Team Losing'
grouped_difference = pd.merge(grouped_year1, grouped_against, 
                              left_on='Acquiring GM', right_on='Losing GM', 
                              suffixes=('_acquired', '_losing'))

# Calculate the final ratio by dividing the AAV_to_WS of acquired over the AAV_to_WS of losing
grouped_difference['final_ratio'] = grouped_difference['Cost of Win Share_losing'] / grouped_difference['Cost of Win Share_acquired']

# Select only the relevant columns for the result
grouped_difference = grouped_difference[['Team Acquiring','Acquiring GM', 'final_ratio']]

# %%
grouped_difference
# Out:
#    Team Acquiring       Acquiring GM  final_ratio
# 0             MIA      Andy Elisburg     1.375659
# 1             TOR      Bobby Webster     0.529115
# 2             BOS       Brad Stevens     2.046187
# 3             SAS       Brian Wright     0.274268
# 4             DEN       Calvin Booth     9.022556
# 5             IND      Chad Buchanan     0.959281
# 6             PHI        Daryl Morey     1.056028
# 7             PHO        James Jones     1.315593
# 8             POR         Joe Cronin     0.649183
# 9             MIL          Jon Horst     0.541850
# 10            UTA       Justin Zanik     1.775148
# 11            CLE        Koby Altman     0.962549
# 12            ATL      Landry Fields     0.734956
# 13            CHI      Marc Eversley     1.969637
# 14            LAC     Michael Winger     1.162433
# 15            GSW  Mike Dunleavy Jr.     0.806723
# 16            CHO      Mitch Kupchak     1.343024
# 17            SAC       Monte McNair     0.908367
# 18            DAL      Nico Harrison     1.538331
# 19            HOU       Rafael Stone     0.169870
# 20            LAL        Rob Pelinka     0.242611
# 21            MIN       Sachin Gupta     2.928571
# 22            OKC         Sam Presti     0.641021
# 23            NYK        Scott Perry     1.626185
# 24            BRK         Sean Marks     1.232753
# 25            MIN       Tim Connelly     2.241315
# 26            WAS     Tommy Sheppard     1.893800
# 27            NOP     Trajan Langdon     1.212490
# 28            ATL     Travis Schlenk     6.730435
# 29            LAC       Trent Redden          inf
# 30            DET        Troy Weaver     0.434345
# 31            WAS       Will Dawkins     0.163575
# 32            MEM       Zach Kleiman     0.394064

# %%
grouped_difference = grouped_difference[np.isfinite(grouped_difference['final_ratio'])]

# %%
import matplotlib.image as mpimg
from PIL import Image

# %%
# Set up the plot size with reduced height
plt.figure(figsize=(10, 10))  # Adjust the height here

# Create a horizontal bar chart using seaborn
sns.barplot(y='Acquiring GM', x='final_ratio', data=grouped_difference, color='gray')

# Add labels and title
plt.title('Cost of Win Share Lost Divided by Cost of Win Share Acquired')
plt.xlabel('Cost of Win Shares - Lost/Acquired Ratio')
plt.ylabel('Acquiring GM')

# Set the x-axis limits to show only positive values
plt.xlim(0, plt.xlim()[1])  # Lower limit is set to 0, upper limit remains unchanged

# Set the y-axis limits to keep bars within a certain height
plt.ylim(-0.5, len(grouped_difference) - 0.5)  # Adjust y-axis limits to fit the number of bars

# Add a black reference line for the modeled cost of a win share
plt.axvline(x=1, color='black', linestyle='--')

# Add an annotation with a multi-line text box aligned to the far right
plt.text(
    x=plt.xlim()[1] * 0.98,  # Position near the far right of the x-axis
    y=len(grouped_difference) * 0.5,  # Adjusted vertical position
    s="If number is above 1,\nthe GM is acquiring value more \nefficiently than he is losing\nIf number is below 1,\nthe GM is acquiring value less \nefficiently than he is losing",
    ha='right',  # Align text to the right
    va='top',  # Vertical alignment to the top
    color='black',
    fontsize=10,
    bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white", linewidth=0.5, alpha=0.9),
)

# Add larger team logos to the right of each bar
for i, (index, row) in enumerate(grouped_difference.iterrows()):
    team_name = row['Team Acquiring']  # Assuming 'Team Acquiring' has the team names
    logo_path = f'C:/Users/kevin/Downloads/logos 4/{team_name}.png'  # Update with actual path to logos
    
    # Load the logo image
    img = Image.open(logo_path)
    
    # Resize the image (width, height) - 100% larger than previous size
    img = img.resize((90, 44), Image.ANTIALIAS)  # Increased size to 90x44
    img = mpimg.imread(logo_path)  # Convert back to numpy array after resizing
    
    # Set the position for the logo to the right of each bar
    plt.imshow(img, aspect='auto', extent=[row['final_ratio'] + 0.1, row['final_ratio'] + 0.7, 
                                            i - 0.4, i + 0.4], zorder=5)

# Align y-axis labels with bars by setting the ticks and labels manually
plt.yticks(ticks=range(len(grouped_difference)), labels=grouped_difference['Acquiring GM'], rotation=0)

# Add a legend for the reference line
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_17420\2895702955.py:42: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((90, 44), Image.ANTIALIAS)  # Increased size to 90x44
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def resize_image(image_path, output_size=(100, 100)):
    img = Image.open(image_path)
    img.thumbnail(output_size, Image.ANTIALIAS)
    return img

# %%
# Set up the plot size with reduced height
plt.figure(figsize=(10, 10))  # Adjust the height here

# Create a horizontal bar chart using seaborn
sns.barplot(y='Acquiring GM', x='final_ratio', data=grouped_difference, color='gray')

# Add labels and title
plt.title('Cost of Win Share Lost Divided by Cost of Win Share Acquired')
plt.xlabel('Cost of Win Shares - Lost/Acquired Ratio')
plt.ylabel('Acquiring GM')

# Set the x-axis limits to show only positive values
plt.xlim(0, plt.xlim()[1])  # Lower limit is set to 0, upper limit remains unchanged

# Set the y-axis limits to keep bars within a certain height
plt.ylim(-0.5, len(grouped_difference) - 0.5)  # Adjust y-axis limits to fit the number of bars

# Add a black reference line for the modeled cost of a win share
plt.axvline(x=1, color='black', linestyle='--')

# Add an annotation with a multi-line text box aligned to the far right
plt.text(
    x=plt.xlim()[1] * 0.98,  # Position near the far right of the x-axis
    y=len(grouped_difference) * 0.5,  # Adjusted vertical position
    s="If number is above 1,\nthe GM is acquiring value more \nefficiently than he is losing\nIf number is below 1,\nthe GM is acquiring value less \nefficiently than he is losing",
    ha='right',  # Align text to the right
    va='top',  # Vertical alignment to the top
    color='black',
    fontsize=10,
    bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white", linewidth=0.5, alpha=0.9),
)

for i, row in grouped_difference.iterrows():
    team_name = row['Team Acquiring']
    logo_path = f'C:/Users/kevin/Downloads/logos 4/{team_name}.png'  # Update with actual path

    try:
        # Resize image before plotting
        img = resize_image(logo_path)
        img_aspect_ratio = img.width / img.height

        # Adjust dimensions
        img_width = 0.7
        img_height = img_width / img_aspect_ratio

        x_start = row['final_ratio'] + 0.05
        x_end = x_start + img_width
        y_center = i
        y_start = y_center - img_height / 2
        y_end = y_center + img_height / 2

        # Plot resized image
        img = mpimg.imread(logo_path)
        plt.imshow(img, aspect='auto', extent=[x_start, x_end, y_start, y_end], zorder=5)
    except FileNotFoundError:
        print(f"Logo not found for {team_name}")
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_17420\566809126.py:3: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img.thumbnail(output_size, Image.ANTIALIAS)

# %%
trades_df[trades_df['Acquiring GM'] == 'Calvin Booth']
# Out:
#      Season Team Acquiring           Acquired Player Team Losing  \
# 78     2022            DEN               Bryn Forbes         SAS
# 134    2023            DEN  Kentavious Caldwell-Pope         WAS
# 135    2023            DEN                 Ish Smith         WAS
# 192    2023            DEN             Thomas Bryant         LAL
#
#     Acquisition Type  Acquiring GM     Losing GM  Year 2  \
# 78             Trade  Calvin Booth  Brian Wright    2023
# 134            Trade  Calvin Booth  Will Dawkins    2024
# 135            Trade  Calvin Booth  Will Dawkins    2024
# 192            Trade  Calvin Booth   Rob Pelinka    2024
#
#                            Helper   AAV  Acquired Player Win Shares Year 1  \
# 78                2022Bryn Forbes   4.5                                0.7
# 134  2023Kentavious Caldwell-Pope  14.0                                4.5
# 135                 2023Ish Smith   1.8                               -0.5
# 192             2023Thomas Bryant   2.5                                0.3
#
#      Acquired Player Win Shares Year 2
# 78                                 NaN
# 134                                4.8
# 135                                NaN
# 192                                NaN

# %%
trades_df[trades_df['Losing GM'] == 'Calvin Booth']
# Out:
#      Season Team Acquiring Acquired Player Team Losing Acquisition Type  \
# 76     2022            BOS         Bol Bol         DEN            Trade
# 77     2022            BOS       PJ Dozier         DEN            Trade
# 136    2023            WAS     Will Barton         DEN            Trade
# 137    2023            WAS    Monté Morris         DEN            Trade
# 193    2023            LAC    Bones Hyland         DEN            Trade
#
#        Acquiring GM     Losing GM  Year 2            Helper   AAV  \
# 76     Brad Stevens  Calvin Booth    2023       2022Bol Bol   2.2
# 77     Brad Stevens  Calvin Booth    2023     2022PJ Dozier   2.0
# 136    Will Dawkins  Calvin Booth    2024   2023Will Barton  13.2
# 137    Will Dawkins  Calvin Booth    2024  2023Monté Morris   9.1
# 193  Michael Winger  Calvin Booth    2024  2023Bones Hyland   2.3
#
#      Acquired Player Win Shares Year 1  Acquired Player Win Shares Year 2
# 76                                 0.0                                NaN
# 77                                 0.0                                NaN
# 136                                0.2                                NaN
# 137                                0.0                                NaN
# 193                                0.5                                0.0

# %%
# Define the grade categories
grade_labels = ['F', 'D', 'C', 'B', 'A']

# Calculate the quantiles for the 'final_ratio' column (5 bins for grades A to F)
grouped_difference['Grade'] = pd.qcut(grouped_difference['final_ratio'], q=5, labels=grade_labels)

# %%
# Calculate the mean and standard deviation of the 'GM_Pct Change' column
mean_gm_pct_change = grouped_difference['final_ratio'].mean()
std_gm_pct_change = grouped_difference['final_ratio'].std()

# Create the 'z score' column by applying the Z-score formula
grouped_difference['z score'] = (grouped_difference['final_ratio'] - mean_gm_pct_change) / std_gm_pct_change

# %%
grouped_difference.sort_values('final_ratio', ascending=False)
# Out:
#    Team Acquiring       Acquiring GM  final_ratio Grade   z score
# 4             DEN       Calvin Booth     9.022556     A  4.129177
# 28            ATL     Travis Schlenk     6.730435     A  2.866391
# 21            MIN       Sachin Gupta     2.928571     A  0.771851
# 25            MIN       Tim Connelly     2.241315     A  0.393225
# 2             BOS       Brad Stevens     2.046187     A  0.285724
# 13            CHI      Marc Eversley     1.969637     A  0.243551
# 26            WAS     Tommy Sheppard     1.893800     A  0.201771
# 10            UTA       Justin Zanik     1.775148     B  0.136402
# 23            NYK        Scott Perry     1.626185     B  0.054335
# 18            DAL      Nico Harrison     1.538331     B  0.005934
# 0             MIA      Andy Elisburg     1.375659     B -0.083686
# 16            CHO      Mitch Kupchak     1.343024     B -0.101665
# 7             PHO        James Jones     1.315593     B -0.116778
# 24            BRK         Sean Marks     1.232753     C -0.162417
# 27            NOP     Trajan Langdon     1.212490     C -0.173580
# 14            LAC     Michael Winger     1.162433     C -0.201157
# 6             PHI        Daryl Morey     1.056028     C -0.259779
# 11            CLE        Koby Altman     0.962549     C -0.311279
# 5             IND      Chad Buchanan     0.959281     C -0.313079
# 17            SAC       Monte McNair     0.908367     D -0.341129
# 15            GSW  Mike Dunleavy Jr.     0.806723     D -0.397127
# 12            ATL      Landry Fields     0.734956     D -0.436665
# 8             POR         Joe Cronin     0.649183     D -0.483919
# 22            OKC         Sam Presti     0.641021     D -0.488416
# 9             MIL          Jon Horst     0.541850     D -0.543052
# 1             TOR      Bobby Webster     0.529115     F -0.550068
# 30            DET        Troy Weaver     0.434345     F -0.602279
# 32            MEM       Zach Kleiman     0.394064     F -0.624471
# 3             SAS       Brian Wright     0.274268     F -0.690469
# 20            LAL        Rob Pelinka     0.242611     F -0.707910
# 19            HOU       Rafael Stone     0.169870     F -0.747985
# 31            WAS       Will Dawkins     0.163575     F -0.751453

# %%
grouped_difference.to_csv('C:/Users/kevin/Downloads/trades GM z scores 2022-2024.csv', index=False)

# %%
trades_df[trades_df['Acquiring GM'] == 'Travis Schlenk']
# Out:
#     Season Team Acquiring Acquired Player Team Losing Acquisition Type  \
# 40    2022            ATL    Delon Wright         SAC            Trade
# 73    2022            ATL   Kevin Knox II         NYK            Trade
#
#       Acquiring GM     Losing GM  Year 2             Helper  AAV  \
# 40  Travis Schlenk  Monte McNair    2023   2022Delon Wright  8.0
# 73  Travis Schlenk   Scott Perry    2023  2022Kevin Knox II  5.8
#
#     Acquired Player Win Shares Year 1  Acquired Player Win Shares Year 2
# 40                                3.6                                NaN
# 73                                0.0                                NaN

# %%
trades_df[trades_df['Losing GM'] == 'Travis Schlenk']
# Out:
#     Season Team Acquiring Acquired Player Team Losing Acquisition Type  \
# 41    2022            BOS       Kris Dunn         ATL            Trade
# 42    2022            BOS  Bruno Fernando         ATL            Trade
# 74    2022            NYK    Solomon Hill         ATL            Trade
# 75    2022            NYK     Cam Reddish         ATL            Trade
#
#     Acquiring GM       Losing GM  Year 2              Helper  AAV  \
# 41  Brad Stevens  Travis Schlenk    2023       2022Kris Dunn  4.0
# 42  Brad Stevens  Travis Schlenk    2023  2022Bruno Fernando  1.8
# 74   Scott Perry  Travis Schlenk    2023    2022Solomon Hill  2.4
# 75   Scott Perry  Travis Schlenk    2023     2022Cam Reddish  4.7
#
#     Acquired Player Win Shares Year 1  Acquired Player Win Shares Year 2
# 41                                0.0                                NaN
# 42                                0.1                                NaN
# 74                                0.0                                NaN
# 75                                0.4                                0.7

# %%
trades_df[trades_df['Acquiring GM'] == 'Sachin Gupta']
# Out:
#     Season Team Acquiring   Acquired Player Team Losing Acquisition Type  \
# 13    2022            MIN     Tauren Prince         CLE            Trade
# 58    2022            MIN  Patrick Beverley         MEM            Trade
#
#     Acquiring GM     Losing GM  Year 2                Helper   AAV  \
# 13  Sachin Gupta   Koby Altman    2023     2022Tauren Prince   7.3
# 58  Sachin Gupta  Zach Kleiman    2023  2022Patrick Beverley  13.0
#
#     Acquired Player Win Shares Year 1  Acquired Player Win Shares Year 2
# 13                                0.0                                NaN
# 58                                4.1                                NaN

# %%
trades_df[trades_df['Losing GM'] == 'Sachin Gupta']
# Out:
#     Season Team Acquiring      Acquired Player Team Losing Acquisition Type  \
# 14    2022            CLE          Ricky Rubio         MIN            Trade
# 56    2022            MEM       Jarrett Culver         MIN            Trade
# 57    2022            MEM  Juancho Hernangómez         MIN            Trade
#
#     Acquiring GM     Losing GM  Year 2                   Helper   AAV  \
# 14   Koby Altman  Sachin Gupta    2023          2022Ricky Rubio  17.0
# 56  Zach Kleiman  Sachin Gupta    2023       2022Jarrett Culver   1.0
# 57  Zach Kleiman  Sachin Gupta    2023  2022Juancho Hernangómez   2.3
#
#     Acquired Player Win Shares Year 1  Acquired Player Win Shares Year 2
# 14                                1.3                                0.7
# 56                                0.1                                NaN
# 57                                0.0                                NaN

# %% [markdown]
# Checked the transactions for Calvin Booth, Travis Schlenk, and Sachin Gupta in my analysis to see why they got A. My initial theory after seeing Calvin Booth is that if you shed a lot of salary you will be graded well but it seems in the other two cases they are taking on just as much salary as they are giving up.

# %% [markdown]
# ### Trying to find patterns and correlations

# %%
df_for = pd.merge(grouped_year1, grouped_difference, on='Acquiring GM', how='inner')
df_against = pd.merge(grouped_against, grouped_difference, left_on='Losing GM', right_on='Acquiring GM', how='inner')

# %%
df_for.columns
# Out:
# Index(['Acquiring GM', 'Team Acquiring_x', 'AAV_sum',
#        'Acquired Player Win Shares Year 1', 'Count', 'Cost of Win Share',
#        'Team Acquiring_y', 'final_ratio', 'Grade'],
#       dtype='object')

# %%
df_against.columns
# Out:
# Index(['Losing GM', 'AAV', 'Acquired Player Win Shares Year 1',
#        'Cost of Win Share', 'Team Acquiring', 'Acquiring GM', 'final_ratio',
#        'Grade'],
#       dtype='object')

# %%
df_for['AAV_sum'].corr(df_for['final_ratio'])
# Out:
# -0.32430265224478166

# %% [markdown]
# This correlation between the sum of salaries is the highest correlation to the final ratio. This suggests that usually for trades bringing on less salary leads to more efficiency in acquiring value for dollars.

# %%
df_against['AAV'].corr(df_for['final_ratio'])
# Out:
# -0.20019683738989233

# %%
df_for['Count'].corr(df_for['final_ratio'])
# Out:
# -0.3048944582626991

# %%
df_for['avg_salary'] = df_for['AAV_sum'] / df_for['Count']

# %%
df_for['avg_salary'].corr(df_for['final_ratio'])
# Out:
# -0.1013483160886167

# %%
df_for['Cost of Win Share'].corr(df_for['final_ratio'])
# Out:
# -0.39420444293579837

# %%
grouped_difference.columns
# Out:
# Index(['Team Acquiring', 'Acquiring GM', 'final_ratio', 'Grade'], dtype='object')

# %% [markdown]
# ### A Second Way of Grading GM - Win Shares Acquired over Lost

# %% [markdown]
# Instead of using the cost per win share, this method analyzes win shares directly. This method may not be as effective because some GMs are managing tanking teams and are not trying to acquire win shares in return. However, it is an additional look and I believe this is more representative of trade performance because GMs are often not around years down the line for future looking trades to pay off in their favor.

# %%
# Merge the two DataFrames on 'Team Acquiring' and 'Team Losing'
grouped_difference2 = pd.merge(grouped_year1, grouped_against, 
                              left_on='Acquiring GM', right_on='Losing GM', 
                              suffixes=('_acquired', '_losing'))

# %%
grouped_difference2.columns
# Out:
# Index(['Acquiring GM', 'Team Acquiring', 'AAV_sum',
#        'Acquired Player Win Shares Year 1_acquired', 'Count',
#        'Cost of Win Share_acquired', 'Losing GM', 'AAV',
#        'Acquired Player Win Shares Year 1_losing', 'Cost of Win Share_losing'],
#       dtype='object')

# %%
# Calculate the final ratio by dividing the AAV_to_WS of acquired over the AAV_to_WS of losing
grouped_difference2['final_ratio'] = grouped_difference2['Acquired Player Win Shares Year 1_acquired'] / grouped_difference2['Acquired Player Win Shares Year 1_losing']

# %%
grouped_difference2
# Out:
#          Acquiring GM Team Acquiring  AAV_sum  \
# 0       Andy Elisburg            MIA     51.5
# 1       Bobby Webster            TOR     38.0
# 2        Brad Stevens            BOS    122.1
# 3        Brian Wright            SAS     41.3
# 4        Calvin Booth            DEN     22.8
# 5       Chad Buchanan            IND    116.7
# 6         Daryl Morey            PHI     74.2
# 7         James Jones            PHO     87.1
# 8          Joe Cronin            POR     31.2
# 9           Jon Horst            MIL     77.1
# 10       Justin Zanik            UTA     67.6
# 11        Koby Altman            CLE     84.9
# 12      Landry Fields            ATL     31.1
# 13      Marc Eversley            CHI     48.8
# 14     Michael Winger            LAC     39.2
# 15  Mike Dunleavy Jr.            GSW     11.9
# 16      Mitch Kupchak            CHO     54.5
# 17       Monte McNair            SAC     73.4
# 18      Nico Harrison            DAL    103.3
# 19       Rafael Stone            HOU     67.8
# 20        Rob Pelinka            LAL    129.3
# 21       Sachin Gupta            MIN     20.3
# 22         Sam Presti            OKC     31.8
# 23        Scott Perry            NYK     42.2
# 24         Sean Marks            BRK    143.5
# 25       Tim Connelly            MIN     28.4
# 26     Tommy Sheppard            WAS     82.1
# 27     Trajan Langdon            NOP     76.8
# 28     Travis Schlenk            ATL     13.8
# 29       Trent Redden            LAC     47.7
# 30        Troy Weaver            DET     91.0
# 31       Will Dawkins            WAS     39.6
# 32       Zach Kleiman            MEM     76.0
#
#     Acquired Player Win Shares Year 1_acquired  Count  \
# 0                                          8.3      2
# 1                                          4.2      4
# 2                                         24.2     12
# 3                                          2.6      7
# 4                                          5.0      4
# 5                                         12.1     19
# 6                                          9.1      4
# 7                                         14.3      8
# 8                                          2.9      5
# 9                                         15.1      5
# 10                                        19.5      9
# 11                                        16.9      5
# 12                                         6.4      6
# 13                                        13.2      3
# 14                                         5.1      7
# 15                                         0.6      2
# 16                                         8.9      9
# 17                                         9.2      9
# 18                                        12.5      7
# 19                                         2.7     14
# 20                                         7.8      7
# 21                                         4.1      2
# 22                                         2.9      8
# 23                                         8.5      7
# 24                                        13.5     15
# 25                                         2.8      2
# 26                                        14.2      6
# 27                                        14.2      7
# 28                                         3.6      2
# 29                                         8.4      3
# 30                                        11.0     10
# 31                                         1.3      4
# 32                                         9.4     13
#
#     Cost of Win Share_acquired          Losing GM    AAV  \
# 0                     6.204819      Andy Elisburg   23.9
# 1                     9.047619      Bobby Webster   45.0
# 2                     5.045455       Brad Stevens   73.3
# 3                    15.884615       Brian Wright   62.3
# 4                     4.560000       Calvin Booth   28.8
# 5                     9.644628      Chad Buchanan  121.2
# 6                     8.153846        Daryl Morey  112.8
# 7                     6.090909        James Jones   60.9
# 8                    10.758621         Joe Cronin  178.1
# 9                     5.105960          Jon Horst   24.9
# 10                    3.466667       Justin Zanik  152.0
# 11                    5.023669        Koby Altman   73.5
# 12                    4.859375      Landry Fields   17.5
# 13                    3.696970      Marc Eversley   51.7
# 14                    7.686275     Michael Winger   41.1
# 15                   19.833333  Mike Dunleavy Jr.    9.6
# 16                    6.123596      Mitch Kupchak   47.7
# 17                    7.978261       Monte McNair   64.5
# 18                    8.264000      Nico Harrison  119.5
# 19                   25.111111       Rafael Stone   27.3
# 20                   16.576923        Rob Pelinka   55.5
# 21                    4.951220       Sachin Gupta   20.3
# 22                   10.965517         Sam Presti   72.4
# 23                    4.964706        Scott Perry   54.9
# 24                   10.629630         Sean Marks  176.9
# 25                   10.142857       Tim Connelly   34.1
# 26                    5.781690     Tommy Sheppard   86.5
# 27                    5.408451     Trajan Langdon   68.2
# 28                    3.833333     Travis Schlenk   12.9
# 29                    5.678571       Trent Redden    1.1
# 30                    8.272727        Troy Weaver   42.4
# 31                   30.461538       Will Dawkins   28.9
# 32                    8.085106       Zach Kleiman   68.5
#
#     Acquired Player Win Shares Year 1_losing  Cost of Win Share_losing  \
# 0                                        2.8                  8.535714
# 1                                        9.4                  4.787234
# 2                                        7.1                 10.323944
# 3                                       14.3                  4.356643
# 4                                        0.7                 41.142857
# 5                                       13.1                  9.251908
# 6                                       13.1                  8.610687
# 7                                        7.6                  8.013158
# 8                                       25.5                  6.984314
# 9                                        9.0                  2.766667
# 10                                      24.7                  6.153846
# 11                                      15.2                  4.835526
# 12                                       4.9                  3.571429
# 13                                       7.1                  7.281690
# 14                                       4.6                  8.934783
# 15                                       0.6                 16.000000
# 16                                       5.8                  8.224138
# 17                                       8.9                  7.247191
# 18                                       9.4                 12.712766
# 19                                       6.4                  4.265625
# 20                                      13.8                  4.021739
# 21                                       1.4                 14.500000
# 22                                      10.3                  7.029126
# 23                                       6.8                  8.073529
# 24                                      13.5                 13.103704
# 25                                       1.5                 22.733333
# 26                                       7.9                 10.949367
# 27                                      10.4                  6.557692
# 28                                       0.5                 25.800000
# 29                                       0.0                       inf
# 30                                      11.8                  3.593220
# 31                                       5.8                  4.982759
# 32                                      21.5                  3.186047
#
#     final_ratio
# 0      2.964286
# 1      0.446809
# 2      3.408451
# 3      0.181818
# 4      7.142857
# 5      0.923664
# 6      0.694656
# 7      1.881579
# 8      0.113725
# 9      1.677778
# 10     0.789474
# 11     1.111842
# 12     1.306122
# 13     1.859155
# 14     1.108696
# 15     1.000000
# 16     1.534483
# 17     1.033708
# 18     1.329787
# 19     0.421875
# 20     0.565217
# 21     2.928571
# 22     0.281553
# 23     1.250000
# 24     1.000000
# 25     1.866667
# 26     1.797468
# 27     1.365385
# 28     7.200000
# 29          inf
# 30     0.932203
# 31     0.224138
# 32     0.437209

# %%
grouped_difference2 = grouped_difference2[np.isfinite(grouped_difference2['final_ratio'])]

# %%
# Set up the plot size with reduced height
plt.figure(figsize=(10, 10))  # Adjust the height here

# Create a horizontal bar chart using seaborn
sns.barplot(y='Acquiring GM', x='final_ratio', data=grouped_difference2, color='gray')

# Add labels and title
plt.title('Best GMs by Efficiency')
plt.xlabel('Win Shares Acquired over Lost')
plt.ylabel('Acquiring GM')

# Set the x-axis limits to show only positive values
plt.xlim(0, plt.xlim()[1])  # Lower limit is set to 0, upper limit remains unchanged

# Set the y-axis limits to keep bars within a certain height
plt.ylim(-0.5, len(grouped_difference2) - 0.5)  # Adjust y-axis limits to fit the number of bars

# Add a black reference line for the modeled cost of a win share
plt.axvline(x=1, color='black', linestyle='--')

# Add an annotation with a multi-line text box aligned to the far right
plt.text(
    x=plt.xlim()[1] * 0.98,  # Position near the far right of the x-axis
    y=len(grouped_difference2) * 0.5,  # Adjusted vertical position
    s="If number is above 1,\nthe GM is acquiring more value \nthan he is losing\nIf number is below 1,\nthe GM is acquiring less value \nefficiently than he is losing",
    ha='right',  # Align text to the right
    va='top',  # Vertical alignment to the top
    color='black',
    fontsize=10,
    bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white", linewidth=0.5, alpha=0.9),
)

# Add larger team logos to the right of each bar
for i, (index, row) in enumerate(grouped_difference2.iterrows()):
    team_name = row['Team Acquiring']  # Assuming 'Team Acquiring' has the team names
    logo_path = f'C:/Users/kevin/Downloads/logos 4/{team_name}.png'  # Update with actual path to logos
    
    # Load the logo image
    img = Image.open(logo_path)
    
    # Resize the image (width, height) - 100% larger than previous size
    img = img.resize((90, 44), Image.ANTIALIAS)  # Increased size to 90x44
    img = mpimg.imread(logo_path)  # Convert back to numpy array after resizing
    
    # Set the position for the logo to the right of each bar
    plt.imshow(img, aspect='auto', extent=[row['final_ratio'] + 0.1, row['final_ratio'] + 0.7, 
                                            i - 0.4, i + 0.4], zorder=5)
   

# Align y-axis labels with bars by setting the ticks and labels manually
plt.yticks(ticks=range(len(grouped_difference2)), labels=grouped_difference2['Acquiring GM'], rotation=0)

# Add a legend for the reference line
plt.legend()

# Show the plot
plt.show()
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_17420\1326330567.py:42: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((90, 44), Image.ANTIALIAS)  # Increased size to 90x44
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Define the grade categories
grade_labels = ['F', 'D', 'C', 'B', 'A']

# Calculate the quantiles for the 'final_ratio' column (5 bins for grades A to F)
grouped_difference2['Grade'] = pd.qcut(grouped_difference2['final_ratio'], q=5, labels=grade_labels)

# %%
# Calculate the mean and standard deviation of the 'GM_Pct Change' column
mean_gm_pct_change = grouped_difference2['final_ratio'].mean()
std_gm_pct_change = grouped_difference2['final_ratio'].std()

# Create the 'z score' column by applying the Z-score formula
grouped_difference2['z score'] = (grouped_difference2['final_ratio'] - mean_gm_pct_change) / std_gm_pct_change

# %%
grouped_difference2.sort_values('final_ratio', ascending=False)
# Out:
#          Acquiring GM Team Acquiring  AAV_sum  \
# 28     Travis Schlenk            ATL     13.8
# 4        Calvin Booth            DEN     22.8
# 2        Brad Stevens            BOS    122.1
# 0       Andy Elisburg            MIA     51.5
# 21       Sachin Gupta            MIN     20.3
# 7         James Jones            PHO     87.1
# 25       Tim Connelly            MIN     28.4
# 13      Marc Eversley            CHI     48.8
# 26     Tommy Sheppard            WAS     82.1
# 9           Jon Horst            MIL     77.1
# 16      Mitch Kupchak            CHO     54.5
# 27     Trajan Langdon            NOP     76.8
# 18      Nico Harrison            DAL    103.3
# 12      Landry Fields            ATL     31.1
# 23        Scott Perry            NYK     42.2
# 11        Koby Altman            CLE     84.9
# 14     Michael Winger            LAC     39.2
# 17       Monte McNair            SAC     73.4
# 15  Mike Dunleavy Jr.            GSW     11.9
# 24         Sean Marks            BRK    143.5
# 30        Troy Weaver            DET     91.0
# 5       Chad Buchanan            IND    116.7
# 10       Justin Zanik            UTA     67.6
# 6         Daryl Morey            PHI     74.2
# 20        Rob Pelinka            LAL    129.3
# 1       Bobby Webster            TOR     38.0
# 32       Zach Kleiman            MEM     76.0
# 19       Rafael Stone            HOU     67.8
# 22         Sam Presti            OKC     31.8
# 31       Will Dawkins            WAS     39.6
# 3        Brian Wright            SAS     41.3
# 8          Joe Cronin            POR     31.2
#
#     Acquired Player Win Shares Year 1_acquired  Count  \
# 28                                         3.6      2
# 4                                          5.0      4
# 2                                         24.2     12
# 0                                          8.3      2
# 21                                         4.1      2
# 7                                         14.3      8
# 25                                         2.8      2
# 13                                        13.2      3
# 26                                        14.2      6
# 9                                         15.1      5
# 16                                         8.9      9
# 27                                        14.2      7
# 18                                        12.5      7
# 12                                         6.4      6
# 23                                         8.5      7
# 11                                        16.9      5
# 14                                         5.1      7
# 17                                         9.2      9
# 15                                         0.6      2
# 24                                        13.5     15
# 30                                        11.0     10
# 5                                         12.1     19
# 10                                        19.5      9
# 6                                          9.1      4
# 20                                         7.8      7
# 1                                          4.2      4
# 32                                         9.4     13
# 19                                         2.7     14
# 22                                         2.9      8
# 31                                         1.3      4
# 3                                          2.6      7
# 8                                          2.9      5
#
#     Cost of Win Share_acquired          Losing GM    AAV  \
# 28                    3.833333     Travis Schlenk   12.9
# 4                     4.560000       Calvin Booth   28.8
# 2                     5.045455       Brad Stevens   73.3
# 0                     6.204819      Andy Elisburg   23.9
# 21                    4.951220       Sachin Gupta   20.3
# 7                     6.090909        James Jones   60.9
# 25                   10.142857       Tim Connelly   34.1
# 13                    3.696970      Marc Eversley   51.7
# 26                    5.781690     Tommy Sheppard   86.5
# 9                     5.105960          Jon Horst   24.9
# 16                    6.123596      Mitch Kupchak   47.7
# 27                    5.408451     Trajan Langdon   68.2
# 18                    8.264000      Nico Harrison  119.5
# 12                    4.859375      Landry Fields   17.5
# 23                    4.964706        Scott Perry   54.9
# 11                    5.023669        Koby Altman   73.5
# 14                    7.686275     Michael Winger   41.1
# 17                    7.978261       Monte McNair   64.5
# 15                   19.833333  Mike Dunleavy Jr.    9.6
# 24                   10.629630         Sean Marks  176.9
# 30                    8.272727        Troy Weaver   42.4
# 5                     9.644628      Chad Buchanan  121.2
# 10                    3.466667       Justin Zanik  152.0
# 6                     8.153846        Daryl Morey  112.8
# 20                   16.576923        Rob Pelinka   55.5
# 1                     9.047619      Bobby Webster   45.0
# 32                    8.085106       Zach Kleiman   68.5
# 19                   25.111111       Rafael Stone   27.3
# 22                   10.965517         Sam Presti   72.4
# 31                   30.461538       Will Dawkins   28.9
# 3                    15.884615       Brian Wright   62.3
# 8                    10.758621         Joe Cronin  178.1
#
#     Acquired Player Win Shares Year 1_losing  Cost of Win Share_losing  \
# 28                                       0.5                 25.800000
# 4                                        0.7                 41.142857
# 2                                        7.1                 10.323944
# 0                                        2.8                  8.535714
# 21                                       1.4                 14.500000
# 7                                        7.6                  8.013158
# 25                                       1.5                 22.733333
# 13                                       7.1                  7.281690
# 26                                       7.9                 10.949367
# 9                                        9.0                  2.766667
# 16                                       5.8                  8.224138
# 27                                      10.4                  6.557692
# 18                                       9.4                 12.712766
# 12                                       4.9                  3.571429
# 23                                       6.8                  8.073529
# 11                                      15.2                  4.835526
# 14                                       4.6                  8.934783
# 17                                       8.9                  7.247191
# 15                                       0.6                 16.000000
# 24                                      13.5                 13.103704
# 30                                      11.8                  3.593220
# 5                                       13.1                  9.251908
# 10                                      24.7                  6.153846
# 6                                       13.1                  8.610687
# 20                                      13.8                  4.021739
# 1                                        9.4                  4.787234
# 32                                      21.5                  3.186047
# 19                                       6.4                  4.265625
# 22                                      10.3                  7.029126
# 31                                       5.8                  4.982759
# 3                                       14.3                  4.356643
# 8                                       25.5                  6.984314
#
#     final_ratio Grade   z score
# 28     7.200000     A  3.360875
# 4      7.142857     A  3.326660
# 2      3.408451     A  1.090684
# 0      2.964286     A  0.824740
# 21     2.928571     A  0.803356
# 7      1.881579     A  0.176469
# 25     1.866667     A  0.167541
# 13     1.859155     B  0.163043
# 26     1.797468     B  0.126108
# 9      1.677778     B  0.054443
# 16     1.534483     B -0.031354
# 27     1.365385     B -0.132602
# 18     1.329787     B -0.153916
# 12     1.306122     C -0.168085
# 23     1.250000     C -0.201689
# 11     1.111842     C -0.284411
# 14     1.108696     C -0.286295
# 17     1.033708     C -0.331193
# 15     1.000000     C -0.351376
# 24     1.000000     D -0.351376
# 30     0.932203     D -0.391969
# 5      0.923664     D -0.397082
# 10     0.789474     D -0.477429
# 6      0.694656     D -0.534201
# 20     0.565217     D -0.611702
# 1      0.446809     F -0.682600
# 32     0.437209     F -0.688347
# 19     0.421875     F -0.697528
# 22     0.281553     F -0.781546
# 31     0.224138     F -0.815924
# 3      0.181818     F -0.841263
# 8      0.113725     F -0.882033

# %%
grouped_difference2.to_csv('C:/Users/kevin/Downloads/trades GM z scores acquired over lost 2022-2024.csv', index=False)
